# %%
import os
import firebase_admin
from firebase_admin import credentials, firestore
import vertexai
from vertexai.language_models import TextEmbeddingModel
from google.cloud import storage
import json
import time
from dotenv import load_dotenv

# %%
# uploading the environment variables and get the API key
load_dotenv()
AWS_ACCESS_KEY = os.getenv("AWS_ACCESS_KEY")
AWS_SECRET_KEY = os.getenv("AWS_SECRET_KEY")

# Asegurar que Vertex AI use las credenciales correctas
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

BUCKET_NAME = 'embeddings_bucket_backup'
storage_client = storage.Client()
bucket = storage_client.bucket(BUCKET_NAME)

# %%
# Inicialización
cred = credentials.Certificate('../../../bubbo-dfba0-47e395cdcdc7.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

PROJECT_ID = "bubbo-dfba0"
REGION = "us-central1"
MODEL_ID = "text-multilingual-embedding-002"
vertexai.init(project=PROJECT_ID, location=REGION)
model = TextEmbeddingModel.from_pretrained(MODEL_ID)

# %%
#### Esta celda ELIMIMNA TODOS LOS JSON de un bucket OJO!!!
'''
from google.cloud import storage

# Inicializa el cliente
client = storage.Client()

# Nombre del bucket y prefijo de la carpeta
bucket_name = 'embeddings_new_bucket'
prefix = 'embeddings/movies_and_series/'

# Accede al bucket
bucket = client.bucket(bucket_name)

# Lista los blobs con ese prefijo
blobs = client.list_blobs(bucket_name, prefix=prefix)

# Borra solo los archivos JSON, sin eliminar carpetas
for blob in blobs:
    if blob.name.endswith('.json'):
        print(f'Eliminando: {blob.name}')
        blob.delete()

print("Archivos JSON eliminados.")
'''
# Out:
# Eliminando: embeddings/movies_and_series/100001460.json
# Eliminando: embeddings/movies_and_series/100003875.json
# Eliminando: embeddings/movies_and_series/1000046231.json
# Eliminando: embeddings/movies_and_series/100005364.json
# Eliminando: embeddings/movies_and_series/1000058493.json
# Eliminando: embeddings/movies_and_series/100006911.json
# Eliminando: embeddings/movies_and_series/100007149.json
# Eliminando: embeddings/movies_and_series/100008988.json
# Eliminando: embeddings/movies_and_series/100009282.json
# Eliminando: embeddings/movies_and_series/100009943.json
# Eliminando: embeddings/movies_and_series/100011416.json
# Eliminando: embeddings/movies_and_series/100012037.json
# Eliminando: embeddings/movies_and_series/100015183.json
# Eliminando: embeddings/movies_and_series/100015678.json
# Eliminando: embeddings/movies_and_series/100015690.json
# Eliminando: embeddings/movies_and_series/100015706.json
# Eliminando: embeddings/movies_and_series/100016921.json
# ...

# %%
import vertexai
from vertexai.language_models import TextEmbeddingModel
from google.cloud import bigquery, storage
import pandas as pd
import json
import os
import time


# Configuración
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"
PROJECT = "bubbo-dfba0"
LOCATION = "europe-southwest1"
BUCKET_NAME = "embeddings_new_bucket"
GCS_PREFIX = "embeddings/movies_and_series"
BQ_QUERY = """
    SELECT tmdb_id AS ID, title, genres, synopsis 
    FROM `bubbo-dfba0.content.best_content_translated_py`
    LIMIT 250000
    OFFSET 48615
"""
EMBEDDING_MODEL = "text-multilingual-embedding-002"
BATCH_SIZE = 11  # Solo 10 registros

# Inicializar APIs
vertexai.init(project=PROJECT, location=LOCATION)
bq_client = bigquery.Client(project=PROJECT)
storage_client = storage.Client(project=PROJECT)

# Cargar el modelo de embeddings
try:
    embedding_model = TextEmbeddingModel.from_pretrained(EMBEDDING_MODEL)
    print("Modelo de embeddings cargado correctamente.")
except Exception as e:
    print(f"Error al cargar el modelo de embeddings: {e}")
    raise

def get_data_from_bigquery():
    print("Ejecutando la consulta en BigQuery...")
    job = bq_client.query(BQ_QUERY)
    iterator = job.result()
    rows = list(iterator)

    if not rows:
        print("No se encontraron resultados.")
        return [], []

    data = [{"ID": row["ID"], "title": row["title"], "genres": row["genres"], "synopsis": row["synopsis"]} for row in rows]
    df = pd.DataFrame(data)

    return df['ID'].astype(str).tolist(), df['title'].astype(str).tolist()

def create_embeddings(texts):
    embeddings = embedding_model.get_embeddings(texts)
    return [embedding.values for embedding in embeddings]

def upload_embeddings_to_gcs(ids, titles):
    for id, text in zip(ids, titles):
        gcs_path = f"{GCS_PREFIX}/{id}.json"
        blob = storage_client.bucket(BUCKET_NAME).blob(gcs_path)

        # Validar si el archivo ya existe en GCS
        if blob.exists():
            print(f"El embedding de ID {id} ya existe en GCS. Saltando...")
            continue

        # Si no existe, generar y subir
        embedding = embedding_model.get_embeddings([text])[0].values
        time.sleep(0.4)
        with open(f"/tmp/{id}.json", "w") as f:
            json.dump({"id": id, "embedding": embedding}, f)

        blob.upload_from_filename(f"/tmp/{id}.json")
        print(f"Embedding de ID {id} subido a: {gcs_path}")

# MAIN
if __name__ == "__main__":
    ids, titles = get_data_from_bigquery()
    
    if ids:
        upload_embeddings_to_gcs(ids, titles)
    else:
        print("No se encontraron IDs para procesar.")
# Out:
# Modelo de embeddings cargado correctamente.
# Ejecutando la consulta en BigQuery...
# El embedding de ID 95894 ya existe en GCS. Saltando...
# El embedding de ID 116003 ya existe en GCS. Saltando...
# El embedding de ID 49988 ya existe en GCS. Saltando...
# El embedding de ID 95898 ya existe en GCS. Saltando...
# Embedding de ID 49990 subido a: embeddings/movies_and_series/49990.json
# Embedding de ID 49992 subido a: embeddings/movies_and_series/49992.json
# Embedding de ID 116057 subido a: embeddings/movies_and_series/116057.json
# Embedding de ID 802384 subido a: embeddings/movies_and_series/802384.json
# Embedding de ID 146933 subido a: embeddings/movies_and_series/146933.json
# Embedding de ID 74979 subido a: embeddings/movies_and_series/74979.json
# Embedding de ID 115903 subido a: embeddings/movies_and_series/115903.json
# Embedding de ID 116101 subido a: embeddings/movies_and_series/116101.json
# Embedding de ID 116095 subido a: embeddings/movies_and_series/116095.json
# ...

# %%
########## VALIDADOR
from google.cloud import bigquery, storage
import os

# Config (ajustá si estás en otro archivo)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
BUCKET_NAME = "embeddings_new_bucket"
GCS_PREFIX = "embeddings/movies_and_series"

# Inicializar clientes
bq_client = bigquery.Client(project=PROJECT)
storage_client = storage.Client(project=PROJECT)

# 1. Obtener todos los IDs desde BigQuery
def get_all_ids_from_bigquery():
    query = "SELECT tmdb_id AS ID FROM `bubbo-dfba0.content.best_content_translated_py`"
    query_job = bq_client.query(query)
    results = query_job.result()
    return set(str(row.ID) for row in results)

# 2. Obtener todos los archivos existentes en GCS
def get_all_ids_in_gcs():
    bucket = storage_client.bucket(BUCKET_NAME)
    blobs = bucket.list_blobs(prefix=GCS_PREFIX + "/")
    ids_in_gcs = set()

    for blob in blobs:
        filename = blob.name.split("/")[-1]
        if filename.endswith(".json"):
            id_str = filename.replace(".json", "")
            ids_in_gcs.add(id_str)

    return ids_in_gcs

# 3. Comparar y mostrar faltantes
def find_missing_embeddings():
    print("Validando archivos en GCS contra BigQuery...")

    bq_ids = get_all_ids_from_bigquery()
    gcs_ids = get_all_ids_in_gcs()

    missing_ids = sorted(bq_ids - gcs_ids)

    print(f"Total en BigQuery: {len(bq_ids)}")
    print(f"Total en GCS: {len(gcs_ids)}")
    print(f"Faltan: {len(missing_ids)} embeddings")

    if missing_ids:
        print("Algunos ejemplos:", missing_ids[:10])

    return missing_ids

# Ejecutar validador
missing_ids = find_missing_embeddings()
# Out:
# Validando archivos en GCS contra BigQuery...
# Total en BigQuery: 444746
# Total en GCS: 444747
# Faltan: 0 embeddings

# %%
def get_all_ids_from_bigquery_ordered():
    query = "SELECT tmdb_id AS ID FROM `bubbo-dfba0.content.best_content_translated_py` ORDER BY ID"
    query_job = bq_client.query(query)
    results = query_job.result()
    return [str(row.ID) for row in results]

# Buscar posición del ID específico
def find_position_of_id(target_id="10000"):
    all_ids = get_all_ids_from_bigquery_ordered()
    if target_id in all_ids:
        position = all_ids.index(target_id)
        print(f"El ID {target_id} está en la posición {position} (índice basado en 0).")
        return position
    else:
        print(f"El ID {target_id} no se encuentra en la tabla.")
        return None

# Llamar a la función
find_position_of_id()
# Out:
# El ID 10000 está en la posición 2 (índice basado en 0).
# 2

# %%
# Celda para crear el endpoint que luego usaremos para leer vertex
from google.cloud import aiplatform_v1

PROJECT  = "bubbo-dfba0"
LOCATION = "europe-southwest1"  # región soportada por Matching Engine

# 1) Cliente apuntando al endpoint regional
client = aiplatform_v1.IndexEndpointServiceClient(
    client_options={
        "api_endpoint": f"{LOCATION}-aiplatform.googleapis.com"
    }
)

# 2) Parent con la región correcta
parent = f"projects/{PROJECT}/locations/{LOCATION}"

# 3) Nombre descriptivo para tu endpoint alpha
index_endpoint = aiplatform_v1.IndexEndpoint(
    display_name="alpha-recs-movies_and_tv_shows-hnsw-europe-southwest1"
)

# 4) Verificar si ya existe
existing = client.list_index_endpoints(parent=parent)
if any(ep.display_name == index_endpoint.display_name for ep in existing):
    print("Ya existe un endpoint con ese nombre. Aborta o cambia el nombre.")
else:
    # 5) Crear
    op = client.create_index_endpoint(
        parent=parent,
        index_endpoint=index_endpoint
    )
    print("Creando endpoint…")
    ep = op.result()
    print(f"Endpoint creado: {ep.name}")
# Out:
# Creando endpoint…
# Endpoint creado: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272

# %%
# para archivo all_embeddings (previo a generar el index)

import os
import json
from google.cloud import storage

# Configuraciones
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "bubbo-dfba0-47e395cdcdc7.json"
PROJECT = "bubbo-dfba0"
BUCKET_NAME = "embeddings_new_bucket"
GCS_PREFIX = "embeddings/movies_and_series"
OUTPUT_FILE = "/tmp/all_embeddings.jsonl"
GCS_OUTPUT_PATH = "embeddings/index_data/all_embeddings.jsonl"

# Inicializar cliente
storage_client = storage.Client(project=PROJECT)
bucket = storage_client.bucket(BUCKET_NAME)

# Descargar todos los JSON y convertir a JSONL
blobs = bucket.list_blobs(prefix=GCS_PREFIX)

with open(OUTPUT_FILE, "w") as jsonl_file:
    for blob in blobs:
        if blob.name.endswith(".json"):
            content = blob.download_as_text()
            data = json.loads(content)

            if "id" in data and "embedding" in data:
                jsonl_file.write(json.dumps(data) + "\n")

# Subir el archivo consolidado a GCS
output_blob = bucket.blob(GCS_OUTPUT_PATH)
output_blob.upload_from_filename(OUTPUT_FILE)
print(f"Archivo de embeddings consolidado subido a: gs://{BUCKET_NAME}/{GCS_OUTPUT_PATH}")

# %%
from google.cloud import storage
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"
client = storage.Client(project="bubbo-dfba0")
blob = client.bucket("embeddings_new_bucket").blob("embeddings/index_data/all_embeddings.jsonl")

count = 0
with blob.open("rt") as stream:
    for _ in stream:
        count += 1

print(f"Líneas en all_embeddings.jsonl: {count}")
# Out:
# Líneas en all_embeddings.jsonl: 444746

# %%
# Para verificar si están normalizados los embeddings o no:

from google.cloud import storage
import json
import math


# Configurar tu proyecto
BUCKET_NAME = "embeddings_new_bucket"  # Reemplazar por tu bucket real
FILE_PATH = "embeddings/index_data/all_embeddings.jsonl"  # Archivo maestro o cualquier archivo individual

# Inicializar cliente de GCS
storage_client = storage.Client()

# Descargar y leer el archivo
bucket = storage_client.bucket(BUCKET_NAME)
blob = bucket.blob(FILE_PATH)
content = blob.download_as_text()

# Parsear el archivo línea por línea (cada línea es un JSON)
lines = content.strip().split("\n")

# Tomar hasta 100 embeddings
sample_size = min(100, len(lines))
sample_lines = lines[:sample_size]

# Calcular normas
normas = []

for line in sample_lines:
    data = json.loads(line)
    embedding = data["embedding"]
    norma = math.sqrt(sum(x**2 for x in embedding))
    normas.append(norma)

# Resultados
print(f"Normas calculadas para {sample_size} embeddings:")
for i, n in enumerate(normas):
    print(f"Embedding {i+1}: Norma = {n:.4f}")

# Análisis rápido
promedio = sum(normas) / len(normas)
print(f"\nPromedio de norma: {promedio:.4f}")

if 0.95 <= promedio <= 1.05:
    print("Parece que los embeddings están normalizados.")
else:
    print("Los embeddings NO parecen estar normalizados.")
# Out:
# Normas calculadas para 100 embeddings:
# Embedding 1: Norma = 1.0000
# Embedding 2: Norma = 1.0000
# Embedding 3: Norma = 1.0000
# Embedding 4: Norma = 1.0000
# Embedding 5: Norma = 1.0000
# Embedding 6: Norma = 1.0000
# Embedding 7: Norma = 1.0000
# Embedding 8: Norma = 1.0000
# Embedding 9: Norma = 1.0000
# Embedding 10: Norma = 1.0000
# Embedding 11: Norma = 1.0000
# Embedding 12: Norma = 1.0000
# Embedding 13: Norma = 1.0000
# Embedding 14: Norma = 1.0000
# Embedding 15: Norma = 1.0000
# Embedding 16: Norma = 1.0000
# Embedding 17: Norma = 1.0000
# Embedding 18: Norma = 1.0000
# Embedding 19: Norma = 1.0000
# Embedding 20: Norma = 1.0000
# Embedding 21: Norma = 1.0000
# Embedding 22: Norma = 1.0000
# Embedding 23: Norma = 1.0000
# Embedding 24: Norma = 1.0000
# Embedding 25: Norma = 1.0000
# Embedding 26: Norma = 1.0000
# Embedding 27: Norma = 1.0000
# Embedding 28: Norma = 1.0000
# Embedding 29: Norma = 1.0000
# Embedding 30: Norma = 1.0000
# Embedding 31: Norma = 1.0000
# ...

# %%
#creando el index

from google.cloud import aiplatform
import os


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"


# Inicializar el cliente
aiplatform.init(
    project="bubbo-dfba0",
    location="europe-southwest1",
    staging_bucket="gs://embeddings_new_bucket"
)

# Crear el índice utilizando el algoritmo Tree-AH
index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
    display_name="index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1",
    contents_delta_uri="gs://embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl",
    dimensions=768,
    approximate_neighbors_count=250,
    distance_measure_type="COSINE_DISTANCE",
    index_update_method="STREAM_UPDATE"
)

print(f"Índice creado correctamente: {index.resource_name}")
# Out:
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696/operations/7376184805609701376
# MatchingEngineIndex created. Resource name: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696
# To use this MatchingEngineIndex in another session:
# index = aiplatform.MatchingEngineIndex('projects/75629471929/locations/europe-southwest1/indexes/355467711213469696')
# Índice creado correctamente: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696

# %%
# consultando google cloud storage
import gcsfs

fs = gcsfs.GCSFileSystem(token="../../../bubbo-dfba0-47e395cdcdc7.json")
with fs.open('embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl') as f:
    for i in range(5):
        print(f.readline())


fs.info('embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl')
# Out:
# b'{"id": "100", "embedding": [-0.0009217166807502508, -0.027816399931907654, 0.042348381131887436, 0.06346812844276428, -0.030670298263430595, 0.027489224448800087, 0.0314815454185009, 0.010220708325505257, 0.023876585066318512, 0.011568091809749603, -0.015477398410439491, -0.009889459237456322, -0.022833410650491714, -0.030152367427945137, -0.020773785188794136, -0.0022359585855156183, -0.0069099594838917255, -0.06232764944434166, 0.008681670762598515, 0.056596413254737854, -0.08407587558031082, 0.039964426308870316, 0.06256385147571564, -0.04063131660223007, -0.04794082045555115, 0.03362669423222542, 0.029440846294164658, 0.0687476098537445, 0.054691143333911896, 0.08941961079835892, -0.0009745663264766335, -0.0016498188488185406, -0.0034676860086619854, 0.026875585317611694, -0.08315390348434448, 0.021503912284970284, -0.020892759785056114, -0.003366834716871381, 0.042940638959407806, 0.06786756217479706, 0.0030169568490236998, -0.10298775881528854, -0.018486252054572105, 0.044562
# ...

# %%
import json
import gcsfs

# Inicializar GCS
fs = gcsfs.GCSFileSystem(token="../../../bubbo-dfba0-47e395cdcdc7.json")

# Ruta al archivo en GCS
file_path = 'embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl'

# Leer y validar dimensiones
with fs.open(file_path, 'r') as f:
    for i in range(5):  # Solo mostramos las primeras 5 líneas
        line = f.readline()
        data = json.loads(line)
        print(f"Línea {i + 1}: ID = {data['id']}, Dimensión = {len(data['embedding'])}")
# Out:
# Línea 1: ID = 100, Dimensión = 768
# Línea 2: ID = 1000, Dimensión = 768
# Línea 3: ID = 10000, Dimensión = 768
# Línea 4: ID = 100000, Dimensión = 768
# Línea 5: ID = 1000000, Dimensión = 768

# %%
from google.cloud import aiplatform

aiplatform.init(
    project="bubbo-dfba0",
    location="europe-southwest1",
)

# Verificar si el índice existe
index = aiplatform.MatchingEngineIndex.list()
for idx in index:
    print(idx.display_name)
# Out:
# index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1

# %%
from google.cloud import aiplatform

aiplatform.init(
    project="bubbo-dfba0",
    location="europe-southwest1",
)

# Listar los índices creados
indices = aiplatform.MatchingEngineIndex.list()
for idx in indices:
    print(f"Índice encontrado: {idx.display_name}, Resource Name: {idx.resource_name}")
# Out:
# Índice encontrado: index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1, Resource Name: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696

# %%
# Acceder al primer índice de la lista
if indices:
    index = indices[0]  # Selecciona el primer índice (ajusta según el índice que necesites)

    # Consultar los detalles completos del índice
    print(index.gca_resource)  # Esto te dará detalles completos del recurso del índice.
else:
    print("No se encontraron índices.")
# Out:
# name: "projects/75629471929/locations/europe-southwest1/indexes/355467711213469696"
# display_name: "index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1"
# metadata_schema_uri: "gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml"
# metadata {
#   struct_value {
#     fields {
#       key: "config"
#       value {
#         struct_value {
#           fields {
#             key: "shardSize"
#             value {
#               string_value: "SHARD_SIZE_MEDIUM"
#             }
#           }
#           fields {
#             key: "distanceMeasureType"
#             value {
#               string_value: "COSINE_DISTANCE"
#             }
#           }
#           fields {
#             key: "dimensions"
#             value {
#               number_value: 768
#             }
#           }
#           fields {
#             key: "approximateNeighborsCount"
#             value {
#               number_value: 250
#             }
# ...

# %%
index = aiplatform.MatchingEngineIndex(index_name="projects/75629471929/locations/europe-southwest1/indexes/355467711213469696")
print(index.gca_resource)
# Out:
# name: "projects/75629471929/locations/europe-southwest1/indexes/355467711213469696"
# display_name: "index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1"
# metadata_schema_uri: "gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml"
# metadata {
#   struct_value {
#     fields {
#       key: "config"
#       value {
#         struct_value {
#           fields {
#             key: "shardSize"
#             value {
#               string_value: "SHARD_SIZE_MEDIUM"
#             }
#           }
#           fields {
#             key: "distanceMeasureType"
#             value {
#               string_value: "COSINE_DISTANCE"
#             }
#           }
#           fields {
#             key: "dimensions"
#             value {
#               number_value: 768
#             }
#           }
#           fields {
#             key: "approximateNeighborsCount"
#             value {
#               number_value: 250
#             }
# ...

# %%
# Ejecutando una búsqueda en el índice
search_results = index.find_neighbors(
    queries=[[0.1, 0.2, 0.3, ..., 0.768]],  # Reemplazar con un vector de consulta real
    num_neighbors=5  # Puedes ajustar este número según lo que quieras
)

print(search_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Ejecutando una búsqueda en el índice
# ----> 2 search_results = index.find_neighbors(
#       3     queries=[[0.1, 0.2, 0.3, ..., 0.768]],  # Reemplazar con un vector de consulta real
#       4     num_neighbors=5  # Puedes ajustar este número según lo que quieras
#       5 )
#       7 print(search_results)
#
# AttributeError: 'MatchingEngineIndex' object has no attribute 'find_neighbors'

# %%
import os
import time
from google.cloud import aiplatform
from google.cloud import storage

# === CONFIGURACIÓN ===
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
LOCATION = "europe-southwest1"
STAGING_BUCKET = "gs://embeddings_new_bucket"
INDEX_NAME = "index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1"
INDEX_URI = "gs://embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl"
DIMENSIONS = 768
ENDPOINT_ID = "5785049643217846272"  # indexEndpoint ya existente
EXPECTED_COUNT = 440_000

# === INICIAR PLATAFORMA ===
aiplatform.init(project=PROJECT, location=LOCATION, staging_bucket=STAGING_BUCKET)

# === VALIDAR: CANTIDAD DE EMBEDDINGS EN EL ARCHIVO ===
def count_jsonl_lines(bucket_name, blob_path):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)
    with blob.open("rt") as f:
        return sum(1 for _ in f)

bucket_name = "embeddings_new_bucket"
blob_path = "embeddings/index_data/all_embeddings.jsonl"
line_count = count_jsonl_lines(bucket_name, blob_path)
print(f"Embeddings detectados en JSONL: {line_count}")
if line_count < EXPECTED_COUNT:
    raise ValueError(f"❌ Archivo incompleto. Solo hay {line_count} embeddings, se esperaban al menos {EXPECTED_COUNT}.")

# === BUSCAR Y ELIMINAR ÍNDICE EXISTENTE (SI HAY UNO) ===
existing_indexes = aiplatform.MatchingEngineIndex.list(filter=f'display_name="{INDEX_NAME}"')
for existing in existing_indexes:
    print(f"Borrando índice previo: {existing.resource_name}")
    existing.delete()
    existing.wait()

# === CREAR NUEVO ÍNDICE ===
start = time.time()
index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
    display_name=INDEX_NAME,
    contents_delta_uri=INDEX_URI,
    dimensions=DIMENSIONS,
    approximate_neighbors_count=250,
    distance_measure_type="COSINE_DISTANCE",
    index_update_method="STREAM_UPDATE"
)
index.wait()
elapsed = time.time() - start
print(f"✅ Índice creado en {elapsed / 60:.1f} minutos: {index.resource_name}")
# Out:
# Embeddings detectados en JSONL: 444746
# Borrando índice previo: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696
# Deleting MatchingEngineIndex : projects/75629471929/locations/europe-southwest1/indexes/355467711213469696
# MatchingEngineIndex deleted. . Resource name: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696
# Deleting MatchingEngineIndex resource: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696
# Delete MatchingEngineIndex backing LRO: projects/75629471929/locations/europe-southwest1/indexes/355467711213469696/operations/2975605019715305472
# MatchingEngineIndex resource projects/75629471929/locations/europe-southwest1/indexes/355467711213469696 deleted.
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296/operations/7099776378479837184
# ...

# %%
import re
# === DESPLEGAR EL ÍNDICE EN EL ENDPOINT EXISTENTE ===
endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name=ENDPOINT_ID)


deployed_index_id = re.sub(r'[^a-zA-Z0-9_]', '_', INDEX_NAME)
if not deployed_index_id[0].isalpha():
    deployed_index_id = f"a_{deployed_index_id}"
deployed_index_id = deployed_index_id[:63]

print(f"Desplegando índice en endpoint {ENDPOINT_ID}...")

endpoint.deploy_index(
    index=index,
    deployed_index_id=deployed_index_id,
    display_name="deployed-alpha-index",
    )
print(f"🚀 Índice desplegado exitosamente en endpoint: {ENDPOINT_ID}")
# Out:
# Desplegando índice en endpoint 5785049643217846272...
# Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272
# Deploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272/operations/1822683515108458496
# MatchingEngineIndexEndpoint index_endpoint Deployed index. Resource name: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272
# 🚀 Índice desplegado exitosamente en endpoint: 5785049643217846272

# %%
import json
import random
from google.cloud import storage

# === Cargar un embedding real del archivo JSONL ===
bucket_name = "embeddings_new_bucket"
blob_path = "embeddings/index_data/all_embeddings.jsonl"

client = storage.Client()
bucket = client.bucket(bucket_name)
blob = bucket.blob(blob_path)

# Leer algunas líneas y elegir una al azar
with blob.open("rt") as f:
    lines = [next(f) for _ in range(100)]  # lee 100 líneas
sample = json.loads(random.choice(lines))
query_embedding = sample["embedding"]
print(f"ID original: {sample['id']}")
# Out:
# ID original: 100000114

# %%
from google.cloud import aiplatform

aiplatform.init(project="bubbo-dfba0", location="europe-southwest1")

endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name="5785049643217846272")

response = endpoint.find_neighbors(
    deployed_index_id="index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe",
    queries=[query_embedding],
    num_neighbors=5,
)

# Verifica que la respuesta tenga datos antes de intentar iterar
if response and len(response[0]) > 0:
    for idx, neighbor in enumerate(response[0]):
        print(f"ID: {neighbor.distance:2.f}, {product_names[neighbor.id]}")
else:
    print("No se encontraron vecinos para la consulta.")
# Out:
# No se encontraron vecinos para la consulta.

# %%
endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name="5785049643217846272")

for deployed_index in endpoint.deployed_indexes:
    print(f"Deployed Index ID: {deployed_index.id}")
    print(f"Display Name: {deployed_index.display_name}")
    print(f"Index Resource: {deployed_index.index}")
# Out:
# Deployed Index ID: index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe
# Display Name: deployed-alpha-index
# Index Resource: projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296

# %%
import numpy as np

# Asegurar tipo float32
query_embedding = np.array(query_embedding, dtype=np.float32).tolist()
print(f"Dimensión del embedding consultado: {len(query_embedding)}, tipo: {type(query_embedding[0])}")
# Out:
# Dimensión del embedding consultado: 768, tipo: <class 'float'>

# %%
from google.cloud import aiplatform

aiplatform.init(project="bubbo-dfba0", location="europe-southwest1")

# Cargar el índice por su nombre
index = aiplatform.MatchingEngineIndex(index_name="projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296")
index_resource = index.gca_resource

print(f"Estado del índice: {index_resource.state}")
if hasattr(index_resource, 'index_stats'):
    print(f"Index stats: {index_resource.index_stats}")
else:
    print("Index stats no disponibles")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 9
#       6 index = aiplatform.MatchingEngineIndex(index_name="projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296")
#       7 index_resource = index.gca_resource
# ----> 9 print(f"Estado del índice: {index_resource.state}")
#      10 if hasattr(index_resource, 'index_stats'):
#      11     print(f"Index stats: {index_resource.index_stats}")
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\proto\message.py:877, in Message.__getattr__(self, key)
#     875 (key, pb_type) = self._get_pb_type_from_key(key)
#     876 if pb_type is None:
# --> 877     raise AttributeError(
#     878         "Unknown field for {}: {}".format(self.__class__.__name__, key)
#     879     )
#     880 pb_value = getattr(self._pb, key)
#     881 marshal = self._meta.marshal
#
# ...

# %%
endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name="5785049643217846272")
for deployed_index in endpoint.deployed_indexes:
    print(f"Deployed Index ID: {deployed_index.id}")
    print(f"Index resource name: {deployed_index.index}")
    print(f"Number of neighbors retrieved per query: {deployed_index.nearest_neighbor_search_config.tree_ah_config.approximate_neighbors_count}")
# Out:
# Deployed Index ID: index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe
# Index resource name: projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 5
#       3 print(f"Deployed Index ID: {deployed_index.id}")
#       4 print(f"Index resource name: {deployed_index.index}")
# ----> 5 print(f"Number of neighbors retrieved per query: {deployed_index.nearest_neighbor_search_config.tree_ah_config.approximate_neighbors_count}")
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\proto\message.py:877, in Message.__getattr__(self, key)
#     875 (key, pb_type) = self._get_pb_type_from_key(key)
#     876 if pb_type is None:
# --> 877     raise AttributeError(
#     878         "Unknown field for {}: {}".format(self.__class__.__name__, key)
# ...

# %%
from google.cloud import storage

client = storage.Client()
bucket = client.get_bucket("embeddings_new_bucket")
blobs = bucket.list_blobs(prefix="embeddings/index_data/")

print("Archivos en embeddings/index_data/:")
for blob in blobs:
    print(f"- {blob.name} ({blob.size / 1024:.1f} KB)")
# Out:
# Archivos en embeddings/index_data/:
# - embeddings/index_data/all_embeddings.jsonl (7388135.2 KB)

# %%
from google.protobuf.json_format import MessageToDict

index = aiplatform.MatchingEngineIndex(index_name="projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296")
index_dict = MessageToDict(index._gca_resource._pb)

import pprint
pprint.pprint(index_dict)
# Out:
# {'createTime': '2025-05-02T20:27:34.670598Z',
#  'deployedIndexes': [{'deployedIndexId': 'index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe',
#                       'displayName': 'deployed-alpha-index',
#                       'indexEndpoint': 'projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272'}],
#  'displayName': 'index-for-alpha-recs-movies-and-tv-shows-tree-ah-europe-southwest1',
#  'encryptionSpec': {},
#  'etag': 'AMEw9yPgMHEIJP-LKqKKBuTelE6mipXSXSLMy7e3BE8VZrO4GJbeV3MSe5krGvzaRVRz',
#  'indexStats': {'shardsCount': 1},
#  'indexUpdateMethod': 'STREAM_UPDATE',
#  'metadata': {'config': {'algorithmConfig': {'treeAhConfig': {}},
#                          'approximateNeighborsCount': 250.0,
#                          'dimensions': 768.0,
#                          'distanceMeasureType': 'COSINE_DISTANCE',
#                          'shardSize': 'SHARD_SIZE_MEDIUM'}},
# ...

# %%
index_endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name="5785049643217846272")
deployed_index = index_endpoint.deployed_indexes[0]

print(f"Deployed index ID: {deployed_index.id}")
print(f"Index resource: {deployed_index.index}")

# Obtener estadísticas del índice
index = aiplatform.MatchingEngineIndex(index_name=deployed_index.index)
stats = index._gca_resource.index_stats

if stats and hasattr(stats, "vectors_count"):
    print(f"🔍 Vectores cargados: {stats.vectors_count}")
else:
    print("⚠️ No se encontró información sobre la cantidad de vectores cargados.")
# Out:
# Deployed index ID: index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe
# Index resource: projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296
# 🔍 Vectores cargados: 0

# %%
from google.cloud import storage

# Verificar si el archivo está accesible
client = storage.Client()
bucket_name = "embeddings_new_bucket"
blob_path = "embeddings/index_data/all_embeddings.jsonl"

bucket = client.bucket(bucket_name)
blob = bucket.blob(blob_path)

if blob.exists():
    print(f"✔️ El archivo {blob_path} está disponible.")
else:
    print(f"⚠️ El archivo {blob_path} no se encontró en el bucket.")
# Out:
# ✔️ El archivo embeddings/index_data/all_embeddings.jsonl está disponible.

# %%
import os
import time
import re
from google.cloud import aiplatform
from google.cloud import storage

# === CONFIGURACIÓN ===
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
LOCATION = "europe-southwest1"
STAGING_BUCKET = "gs://embeddings_new_bucket"
INDEX_NAME = "alpha_recs_movies_tv_tree_ah_eu_sw1"  # nuevo nombre corto
INDEX_URI = "gs://embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl"
DIMENSIONS = 768
ENDPOINT_ID = "projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272"
EXPECTED_COUNT = 440_000

# === INICIAR PLATAFORMA ===
aiplatform.init(project=PROJECT, location=LOCATION, staging_bucket=STAGING_BUCKET)

# Resumen de ejecución
execution_report = {
    "index_name": INDEX_NAME,
    "status": "started",
    "steps": []
}

# === VALIDAR: CANTIDAD DE EMBEDDINGS ===
def count_jsonl_lines(bucket_name, blob_path):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)
    with blob.open("rt") as f:
        return sum(1 for _ in f)

bucket_name = "embeddings_new_bucket"
blob_path = "embeddings/index_data/all_embeddings.jsonl"
line_count = count_jsonl_lines(bucket_name, blob_path)
execution_report["steps"].append(f"Embeddings detectados en JSONL: {line_count}")
print(f"📦 Embeddings detectados en JSONL: {line_count}")

if line_count < EXPECTED_COUNT:
    error_msg = f"❌ Archivo incompleto: {line_count} embeddings, se esperaban al menos {EXPECTED_COUNT}."
    execution_report["status"] = "failed"
    execution_report["steps"].append(error_msg)
    raise ValueError(error_msg)

# === ELIMINAR ÍNDICE EXISTENTE ===
print("🔍 Verificando índices existentes...")
execution_report["steps"].append("Verificando índices existentes...")
existing_indexes = aiplatform.MatchingEngineIndex.list(filter=f'display_name="{INDEX_NAME}"')
for existing in existing_indexes:
    print(f"🗑️ Eliminando índice anterior: {existing.resource_name}")
    execution_report["steps"].append(f"Eliminando índice anterior: {existing.resource_name}")
    existing.delete()
    existing.wait()

# === CREAR NUEVO ÍNDICE ===
print("🛠️ Creando nuevo índice...")
execution_report["steps"].append("Creando nuevo índice...")
start = time.time()
index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
    display_name=INDEX_NAME,
    contents_delta_uri=INDEX_URI,
    dimensions=DIMENSIONS,
    approximate_neighbors_count=250,
    distance_measure_type="COSINE_DISTANCE",
    index_update_method="STREAM_UPDATE"
)
index.wait()
elapsed = time.time() - start
execution_report["steps"].append(f"✅ Índice creado: {index.resource_name} en {elapsed / 60:.1f} minutos.")
print(f"✅ Índice creado en {elapsed / 60:.1f} minutos: {index.resource_name}")

# === DESPLEGAR EN ENDPOINT EXISTENTE ===
print("🚚 Desplegando índice en endpoint existente...")
execution_report["steps"].append(f"Desplegando índice en endpoint: {ENDPOINT_ID}")
endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name=ENDPOINT_ID)

deployed_index_id = re.sub(r'[^a-zA-Z0-9_]', '_', INDEX_NAME)
if not deployed_index_id[0].isalpha():
    deployed_index_id = f"a_{deployed_index_id}"
deployed_index_id = deployed_index_id[:63]

# Eliminar cualquier índice ya desplegado con el mismo ID
for d in endpoint.deployed_indexes:
    if d.id == deployed_index_id:
        print(f"🔄 Eliminando despliegue previo con ID: {deployed_index_id}")
        execution_report["steps"].append(f"🔄 Eliminando despliegue previo con ID: {deployed_index_id}")
        endpoint.undeploy_index(deployed_index_id=d.id)
        time.sleep(5)

endpoint.deploy_index(
    index=index,
    deployed_index_id=deployed_index_id,
    display_name="deployed-alpha-index",
)
execution_report["steps"].append(f"🚀 Índice desplegado exitosamente con ID: {deployed_index_id}")
print(f"🚀 Índice desplegado exitosamente con ID: {deployed_index_id}")

# Actualizar el estado final
execution_report["status"] = "success"
execution_report["steps"].append("Ejecución completada con éxito.")

# Mostrar el reporte final
print("\n🔄 Reporte de ejecución:")
for step in execution_report["steps"]:
    print(step)

# El reporte final está en la variable `execution_report`
# Out:
# 📦 Embeddings detectados en JSONL: 444746
# 🔍 Verificando índices existentes...
# 🛠️ Creando nuevo índice...
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464/operations/768981939792117760
# MatchingEngineIndex created. Resource name: projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464
# To use this MatchingEngineIndex in another session:
# index = aiplatform.MatchingEngineIndex('projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464')
# ✅ Índice creado en 0.7 minutos: projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464
# 🚚 Desplegando índice en endpoint existente...
# Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272
# ...

# %%
# Obtener detalles del índice
index = aiplatform.MatchingEngineIndex('projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464')

# Obtener el recurso del índice
index_resource = index.gca_resource

# Imprimir detalles del recurso
print(f"Detalles del índice: {index_resource}")
# Out:
# Detalles del índice: name: "projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464"
# display_name: "alpha_recs_movies_tv_tree_ah_eu_sw1"
# metadata_schema_uri: "gs://google-cloud-aiplatform/schema/matchingengine/metadata/nearest_neighbor_search_1.0.0.yaml"
# metadata {
#   struct_value {
#     fields {
#       key: "config"
#       value {
#         struct_value {
#           fields {
#             key: "shardSize"
#             value {
#               string_value: "SHARD_SIZE_MEDIUM"
#             }
#           }
#           fields {
#             key: "distanceMeasureType"
#             value {
#               string_value: "COSINE_DISTANCE"
#             }
#           }
#           fields {
#             key: "dimensions"
#             value {
#               number_value: 768
#             }
#           }
#           fields {
#             key: "approximateNeighborsCount"
#             value {
#               number_value: 250
#             }
# ...

# %%
from google.cloud import aiplatform

# Usar el nombre del endpoint correcto y el ID de índice desplegado
index_endpoint_name = "5785049643217846272"  # Este es el endpoint ya existente que confirmamos
index_resource_name = "projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464"  # El nuevo índice creado

# Obtener el endpoint y el índice desplegado
index_endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name=index_endpoint_name)
deployed_index = index_endpoint.deployed_indexes[0]

# Mostrar información del índice desplegado
print(f"Deployed index ID: {deployed_index.id}")
print(f"Index resource: {deployed_index.index}")

# Obtener estadísticas del índice
index = aiplatform.MatchingEngineIndex(index_name=index_resource_name)
index_resource = index.gca_resource
stats = index_resource.index_stats

# Verificar si hay estadísticas disponibles y mostrar la cantidad de vectores
if stats and hasattr(stats, "vectors_count"):
    print(f"🔍 Vectores cargados: {stats.vectors_count}")
else:
    print("⚠️ No se encontró información sobre la cantidad de vectores cargados.")
# Out:
# Deployed index ID: index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe
# Index resource: projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296
# 🔍 Vectores cargados: 0

# %%
# Obtener recurso del índice y estado
index_resource = index.gca_resource
if hasattr(index_resource, "index_stats"):
    print(f"Estadísticas del índice: {index_resource.index_stats}")
else:
    print("⚠️ No se encontraron estadísticas del índice.")
# Out:
# Estadísticas del índice: shards_count: 1

# %%
from google.cloud import aiplatform

aiplatform.init(project="bubbo-dfba0", location="europe-southwest1")

# Obtener todos los endpoints de Matching Engine
endpoints = aiplatform.MatchingEngineIndexEndpoint.list()

for endpoint in endpoints:
    print(f"\n🛰️ Endpoint: {endpoint.resource_name}")
    for deployed_index in endpoint.deployed_indexes:
        print(f"   ↳ Deployed Index ID: {deployed_index.id}")
        print(f"   ↳ Index Resource: {deployed_index.index}")
# Out:
# 🛰️ Endpoint: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272
#    ↳ Deployed Index ID: index_for_alpha_recs_movies_and_tv_shows_tree_ah_europe_southwe
#    ↳ Index Resource: projects/75629471929/locations/europe-southwest1/indexes/1087302650661175296
#    ↳ Deployed Index ID: alpha_recs_movies_tv_tree_ah_eu_sw1
#    ↳ Index Resource: projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464

# %%
import json
from google.cloud import storage

# Configurá el path a tus credenciales si hace falta
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "path/to/tu-clave.json"

# Parámetros
BUCKET_NAME = "embeddings_new_bucket"
BLOB_PATH = "embeddings/index_data/all_embeddings.jsonl"
EXPECTED_DIM = 768
MAX_LINES = 10000  # Líneas a revisar

# Cliente de GCS
client = storage.Client()
bucket = client.bucket(BUCKET_NAME)
blob = bucket.blob(BLOB_PATH)

# Contadores
valid_lines = 0
invalid_lines = 0
invalid_details = []  # Para almacenar detalles de las líneas inválidas

# Validación
with blob.open("rt") as f:
    for i, line in enumerate(f):
        line_errors = []
        try:
            data = json.loads(line)
        except json.JSONDecodeError as e:
            line_errors.append(f"JSON inválido ({e})")
        
        if "id" not in data or not isinstance(data["id"], str):
            line_errors.append("Falta 'id' o no es un string")
        
        if "embedding" not in data:
            line_errors.append("Falta campo 'embedding'")
        elif not isinstance(data["embedding"], list):
            line_errors.append("'embedding' no es una lista")
        elif len(data["embedding"]) != EXPECTED_DIM:
            line_errors.append(f"Dimensión incorrecta ({len(data['embedding'])})")
        elif not all(isinstance(x, (int, float)) for x in data["embedding"]):
            line_errors.append("La lista contiene valores no numéricos")

        if line_errors:
            invalid_lines += 1
            invalid_details.append({"line": i + 1, "errors": line_errors})
        else:
            valid_lines += 1

        # Limitar a las primeras MAX_LINES para evitar revisar todo el archivo
        if i + 1 >= MAX_LINES:
            break

# Resumen
print(f"\n✅ Resumen de la validación:")
print(f"Total de líneas revisadas: {valid_lines + invalid_lines}")
print(f"Líneas válidas: {valid_lines}")
print(f"Líneas inválidas: {invalid_lines}\n")

if invalid_lines > 0:
    print(f"\n❌ Detalles de las líneas inválidas:")
    for detail in invalid_details:
        print(f"Línea {detail['line']} - Errores: {', '.join(detail['errors'])}")
else:
    print("🎉 ¡Todo está bien! No se encontraron líneas inválidas.")

print("\n✅ Validación completada.")
# Out:
# ✅ Resumen de la validación:
# Total de líneas revisadas: 10000
# Líneas válidas: 10000
# Líneas inválidas: 0
#
# 🎉 ¡Todo está bien! No se encontraron líneas inválidas.
#
# ✅ Validación completada.

# %%
import json
import numpy as np
from google.cloud import storage

# Configuramos los parámetros
BUCKET_NAME = "embeddings_new_bucket"
BLOB_PATH = "embeddings/index_data/all_embeddings.jsonl"
EXPECTED_DIM = 768  # Debe ser la dimensión correcta de los embeddings

# Cliente de GCS
client = storage.Client()
bucket = client.bucket(BUCKET_NAME)
blob = bucket.blob(BLOB_PATH)

# Función para comprobar si los valores son válidos (sin NaNs ni Inf)
def is_valid_vector(embedding):
    try:
        # Comprobar que todos los elementos sean números
        embedding_array = np.array(embedding)
        
        # Verificar que la dimensión sea la correcta y que no haya NaNs ni Infs
        if len(embedding_array) != EXPECTED_DIM:
            return False
        if np.any(np.isnan(embedding_array)) or np.any(np.isinf(embedding_array)):
            return False
        return True
    except Exception as e:
        return False

# Función para verificar el formato correcto (id y embedding)
def is_valid_format(data):
    return isinstance(data, dict) and "id" in data and "embedding" in data and isinstance(data["embedding"], list)

# Comprobación de cada línea
valid_lines = 0
invalid_lines = 0
invalid_format_lines = 0
invalid_indices = []

with blob.open("rt") as f:
    for i, line in enumerate(f):
        try:
            data = json.loads(line)
        except json.JSONDecodeError as e:
            invalid_lines += 1
            invalid_indices.append(i+1)
            continue

        # Verificar formato correcto
        if not is_valid_format(data):
            invalid_format_lines += 1
            invalid_indices.append(i+1)
            continue
        
        embedding = data.get("embedding")
        if embedding and is_valid_vector(embedding):
            valid_lines += 1
        else:
            invalid_lines += 1
            invalid_indices.append(i+1)

        if (i + 1) % 1000 == 0:
            print(f"🔍 Revisadas {i + 1} líneas...")

# Resultado
print(f"\n✅ Resumen de la validación de vectores:")
print(f"Total de líneas revisadas: {i + 1}")
print(f"Líneas válidas: {valid_lines}")
print(f"Líneas inválidas: {invalid_lines}")
print(f"Líneas con formato incorrecto: {invalid_format_lines}")
if invalid_lines > 0:
    print(f"Líneas inválidas encontradas en las posiciones: {invalid_indices}")
else:
    print("🎉 ¡Todo está bien! No se encontraron vectores inválidos ni con formato incorrecto.")

print("\n✅ Validación completada.")
# Out:
# 🔍 Revisadas 1000 líneas...
# 🔍 Revisadas 2000 líneas...
# 🔍 Revisadas 3000 líneas...
# 🔍 Revisadas 4000 líneas...
# 🔍 Revisadas 5000 líneas...
# 🔍 Revisadas 6000 líneas...
# 🔍 Revisadas 7000 líneas...
# 🔍 Revisadas 8000 líneas...
# 🔍 Revisadas 9000 líneas...
# 🔍 Revisadas 10000 líneas...
# 🔍 Revisadas 11000 líneas...
# 🔍 Revisadas 12000 líneas...
# 🔍 Revisadas 13000 líneas...
# 🔍 Revisadas 14000 líneas...
# 🔍 Revisadas 15000 líneas...
# 🔍 Revisadas 16000 líneas...
# 🔍 Revisadas 17000 líneas...
# 🔍 Revisadas 18000 líneas...
# 🔍 Revisadas 19000 líneas...
# 🔍 Revisadas 20000 líneas...
# 🔍 Revisadas 21000 líneas...
# 🔍 Revisadas 22000 líneas...
# 🔍 Revisadas 23000 líneas...
# 🔍 Revisadas 24000 líneas...
# 🔍 Revisadas 25000 líneas...
# 🔍 Revisadas 26000 líneas...
# 🔍 Revisadas 27000 líneas...
# 🔍 Revisadas 28000 líneas...
# 🔍 Revisadas 29000 líneas...
# 🔍 Revisadas 30000 líneas...
# 🔍 Revisadas 31000 líneas...
# 🔍 Revisadas 32000 líneas...
# 🔍 Revisadas 33000 líneas...
# ...

# %%
import os
import time
import re
from google.cloud import aiplatform
from google.cloud import storage

# === CONFIGURACIÓN ===
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
LOCATION = "europe-southwest1"
STAGING_BUCKET = "gs://embeddings_new_bucket"
INDEX_NAME = "alpha_recs_movies_tv_tree_ah_eu_sw1"  # nuevo nombre corto
INDEX_URI = "gs://embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl"
DIMENSIONS = 768
ENDPOINT_ID = "projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272"
EXPECTED_COUNT = 440_000

# === INICIAR PLATAFORMA ===
aiplatform.init(project=PROJECT, location=LOCATION, staging_bucket=STAGING_BUCKET)

# Resumen de ejecución
execution_report = {
    "index_name": INDEX_NAME,
    "status": "started",
    "steps": []
}

# === VALIDAR: CANTIDAD DE EMBEDDINGS ===
def count_jsonl_lines(bucket_name, blob_path):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)
    with blob.open("rt") as f:
        return sum(1 for _ in f)

bucket_name = "embeddings_new_bucket"
blob_path = "embeddings/index_data/all_embeddings.jsonl"
line_count = count_jsonl_lines(bucket_name, blob_path)
execution_report["steps"].append(f"Embeddings detectados en JSONL: {line_count}")
print(f"📦 Embeddings detectados en JSONL: {line_count}")

if line_count < EXPECTED_COUNT:
    error_msg = f"❌ Archivo incompleto: {line_count} embeddings, se esperaban al menos {EXPECTED_COUNT}."
    execution_report["status"] = "failed"
    execution_report["steps"].append(error_msg)
    raise ValueError(error_msg)

# === ELIMINAR ÍNDICE EXISTENTE ===
print("🔍 Verificando índices existentes...")
execution_report["steps"].append("Verificando índices existentes...")
existing_indexes = aiplatform.MatchingEngineIndex.list(filter=f'display_name="{INDEX_NAME}"')
for existing in existing_indexes:
    print(f"🗑️ Eliminando índice anterior: {existing.resource_name}")
    execution_report["steps"].append(f"Eliminando índice anterior: {existing.resource_name}")
    existing.delete()
    existing.wait()

# === CREAR NUEVO ÍNDICE ===
print("🛠️ Creando nuevo índice...")
execution_report["steps"].append("Creando nuevo índice...")
start = time.time()
index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
    display_name=INDEX_NAME,
    contents_delta_uri=INDEX_URI,
    dimensions=DIMENSIONS,
    approximate_neighbors_count=250,
    distance_measure_type="COSINE_DISTANCE",
    index_update_method="STREAM_UPDATE"
)
index.wait()
elapsed = time.time() - start
execution_report["steps"].append(f"✅ Índice creado: {index.resource_name} en {elapsed / 60:.1f} minutos.")
print(f"✅ Índice creado en {elapsed / 60:.1f} minutos: {index.resource_name}")

# === DESPLEGAR EN ENDPOINT EXISTENTE ===
print("🚚 Desplegando índice en endpoint existente...")
execution_report["steps"].append(f"Desplegando índice en endpoint: {ENDPOINT_ID}")
endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name=ENDPOINT_ID)

deployed_index_id = re.sub(r'[^a-zA-Z0-9_]', '_', INDEX_NAME)
if not deployed_index_id[0].isalpha():
    deployed_index_id = f"a_{deployed_index_id}"
deployed_index_id = deployed_index_id[:63]

# Eliminar cualquier índice ya desplegado con el mismo ID
for d in endpoint.deployed_indexes:
    if d.id == deployed_index_id:
        print(f"🔄 Eliminando despliegue previo con ID: {deployed_index_id}")
        execution_report["steps"].append(f"🔄 Eliminando despliegue previo con ID: {deployed_index_id}")
        endpoint.undeploy_index(deployed_index_id=d.id)
        time.sleep(5)

endpoint.deploy_index(
    index=index,
    deployed_index_id=deployed_index_id,
    display_name="deployed-alpha-index",
)
execution_report["steps"].append(f"🚀 Índice desplegado exitosamente con ID: {deployed_index_id}")
print(f"🚀 Índice desplegado exitosamente con ID: {deployed_index_id}")

# Actualizar el estado final
execution_report["status"] = "success"
execution_report["steps"].append("Ejecución completada con éxito.")

# Mostrar el reporte final
print("\n🔄 Reporte de ejecución:")
for step in execution_report["steps"]:
    print(step)

# El reporte final está en la variable `execution_report`
# Out:
# 📦 Embeddings detectados en JSONL: 444746
# 🔍 Verificando índices existentes...
# 🗑️ Eliminando índice anterior: projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464
# Deleting MatchingEngineIndex : projects/75629471929/locations/europe-southwest1/indexes/1988867001065406464
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
# ...

# %%
Supuestamente el index quedó desplegandose

# %%
from google.cloud import aiplatform_v1

# Parámetros
project = "bubbo-dfba0"
location = "europe-southwest1"
index_id = "1988867001065406464"
index_name = f"projects/{project}/locations/{location}/indexes/{index_id}"

# Crear cliente en la región correcta
client_options = {"api_endpoint": f"{location}-aiplatform.googleapis.com"}
client = aiplatform_v1.IndexServiceClient(client_options=client_options)

# Obtener el índice
index = client.get_index(name=index_name)

# Mostrar estado de despliegue
if index.deployed_indexes:
    print("🚀 El índice está desplegado actualmente en:")
    for deployed in index.deployed_indexes:
        print(f"🛰️ IndexEndpoint: {deployed.index_endpoint}")
        print(f"📌 Deployed index ID: {deployed.deployed_index_id}")
else:
    print("📭 El índice no está desplegado en ningún endpoint.")
# Out:
# 🚀 El índice está desplegado actualmente en:
# 🛰️ IndexEndpoint: projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272
# 📌 Deployed index ID: alpha_recs_movies_tv_tree_ah_eu_sw1

# %%
import os
import time
import re
from google.cloud import aiplatform
from google.cloud import storage

# === CONFIGURACIÓN ===
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
LOCATION = "europe-southwest1"
STAGING_BUCKET = "gs://embeddings_new_bucket"
INDEX_NAME = "alpha_recs_movies_tv_tree_ah_eu_sw1"
INDEX_URI = "gs://embeddings_new_bucket/embeddings/index_data/all_embeddings.jsonl"
DIMENSIONS = 768
ENDPOINT_ID = "projects/75629471929/locations/europe-southwest1/indexEndpoints/5785049643217846272"
EXPECTED_COUNT = 440_000

aiplatform.init(project=PROJECT, location=LOCATION, staging_bucket=STAGING_BUCKET)

execution_report = {
    "index_name": INDEX_NAME,
    "status": "started",
    "steps": []
}

# === VALIDAR CANTIDAD DE EMBEDDINGS ===
def count_jsonl_lines(bucket_name, blob_path):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)
    with blob.open("rt") as f:
        return sum(1 for _ in f)

bucket_name = "embeddings_new_bucket"
blob_path = "embeddings/index_data/all_embeddings.jsonl"
line_count = count_jsonl_lines(bucket_name, blob_path)
execution_report["steps"].append(f"Embeddings detectados en JSONL: {line_count}")
print(f"Embeddings detectados en JSONL: {line_count}")

if line_count < EXPECTED_COUNT:
    error_msg = f"Archivo incompleto: {line_count} embeddings, se esperaban al menos {EXPECTED_COUNT}."
    execution_report["status"] = "failed"
    execution_report["steps"].append(error_msg)
    raise ValueError(error_msg)
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\storage\blob.py:4423, in Blob._prep_and_do_download(self, file_obj, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    4422 try:
# -> 4423     self._do_download(
#    4424         transport,
#    4425         file_obj,
#    4426         download_url,
#    4427         headers,
#    4428         start,
#    4429         end,
#    4430         raw_download,
#    4431         timeout=timeout,
#    4432         checksum=checksum,
#    4433         retry=retry,
#    4434     )
#    4435 except resumable_media.InvalidResponse as exc:
#
# ...

# %%
# Out:
# Deleting MatchingEngineIndex : projects/75629471929/locations/europe-southwest1/indexes/5502800610321235968
# MatchingEngineIndex deleted. . Resource name: projects/75629471929/locations/europe-southwest1/indexes/5502800610321235968
# Deleting MatchingEngineIndex resource: projects/75629471929/locations/europe-southwest1/indexes/5502800610321235968
# Delete MatchingEngineIndex backing LRO: projects/75629471929/locations/europe-southwest1/indexes/5502800610321235968/operations/1466771601197367296
# MatchingEngineIndex resource projects/75629471929/locations/europe-southwest1/indexes/5502800610321235968 deleted.
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/75629471929/locations/europe-southwest1/indexes/1888098959402991616/operations/5718169649435115520
# MatchingEngineIndex created. Resource name: projects/75629471929/locations/europe-southwest1/indexes/1888098959402991616
# To use this MatchingEngineIndex in another session:
# ...

# %%
from google.cloud import storage

def mostrar_lineas_iniciales(bucket_name, blob_path, n=3):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)

    with blob.open("rt") as f:
        for i in range(n):
            line = f.readline()
            print(f"Línea {i+1}: {line.strip()}")

mostrar_lineas_iniciales(
    bucket_name="embeddings_new_bucket",
    blob_path="embeddings/index_data/all_embeddings.jsonl"
)
# Out:
# Línea 1: {"id": "100", "embedding": [-0.0009217166807502508, -0.027816399931907654, 0.042348381131887436, 0.06346812844276428, -0.030670298263430595, 0.027489224448800087, 0.0314815454185009, 0.010220708325505257, 0.023876585066318512, 0.011568091809749603, -0.015477398410439491, -0.009889459237456322, -0.022833410650491714, -0.030152367427945137, -0.020773785188794136, -0.0022359585855156183, -0.0069099594838917255, -0.06232764944434166, 0.008681670762598515, 0.056596413254737854, -0.08407587558031082, 0.039964426308870316, 0.06256385147571564, -0.04063131660223007, -0.04794082045555115, 0.03362669423222542, 0.029440846294164658, 0.0687476098537445, 0.054691143333911896, 0.08941961079835892, -0.0009745663264766335, -0.0016498188488185406, -0.0034676860086619854, 0.026875585317611694, -0.08315390348434448, 0.021503912284970284, -0.020892759785056114, -0.003366834716871381, 0.042940638959407806, 0.06786756217479706, 0.0030169568490236998, -0.10298775881528854, -0.018486252054572105, 0
# ...

# %%
import json
from google.cloud import storage

def ver_estructura_json_gcs(bucket_name, blob_path, num_entradas=3):
    # Crear un cliente de Google Cloud Storage
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(blob_path)

    # Abrir el archivo en el almacenamiento de GCS
    with blob.open("rt") as f:
        # Leer las primeras 'num_entradas' líneas del archivo JSONL
        for i in range(num_entradas):
            line = f.readline()
            if not line:
                break  # Si no hay más líneas, detener
            # Convertir la línea JSON en un objeto de Python
            json_data = json.loads(line.strip())
            print(f"Línea {i + 1}:")
            print(json_data)  # Mostrar el objeto JSON de la línea
            print("-" * 50)

# Llamar a la función pasando la ubicación del archivo en GCS
ver_estructura_json_gcs(
    bucket_name="embeddings_new_bucket",
    blob_path="embeddings/index_data/all_embeddings.jsonl",
    num_entradas=3
)
# Out:
# Línea 1:
# ...

# %%
import os
import time
import re
from google.cloud import aiplatform
from google.cloud import storage
from google.cloud import bigquery

# === CONFIGURACIÓN ===
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

# Inicializar cliente
client = bigquery.Client(location="europe-southwest1")
dataset_id_destiny = "bubbo-dfba0.content"

# %%
query_title_counts = f"""
SELECT title, COUNT(*) AS count
FROM `{dataset_id_destiny}.unified_content`
GROUP BY title
ORDER BY count DESC
"""

title_counts = client.query(query_title_counts).to_dataframe()
title_counts.head(10)  # Muestra los 10 más comunes
# Out:
# c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\table.py:1900: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#         title  count
# 0   Episode 1  30052
# 1   Episode 2  29692
# 2   Episode 3  28632
# 3   Episode 4  27064
# 4   Episode 5  24802
# 5   Episode 6  23728
# 6   Episode 7  18120
# 7   Episode 8  17092
# 8   Episode 9  13144
# 9  Episode 10  12864

# %%
title_counts
# Out:
#                                  title  count
# 0                            Episode 1  30052
# 1                            Episode 2  29692
# 2                            Episode 3  28632
# 3                            Episode 4  27064
# 4                            Episode 5  24802
# ...                                ...    ...
# 3305891      PROfishing team с.1 с.151      2
# 3305892   Доктор Комаровський с.1 с.86      2
# 3305893  Олександр Пилипенко с.2 с.181      2
# 3305894      Паризькі таємниці с.1 с.2      2
# 3305895                    会读心术的那小子_03      2
#
# [3305896 rows x 2 columns]

# %%
query_tmdb_counts = f"""
SELECT tmdb_id, COUNT(*) AS count
FROM `{dataset_id_destiny}.unified_content`
GROUP BY tmdb_id
ORDER BY count DESC
"""

tmdb_counts = client.query(query_tmdb_counts).to_dataframe()
tmdb_counts.head(10)  # Muestra los 10 más comunes
# Out:
# c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\table.py:1900: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#   tmdb_id  count
# 0     121   1276
# 1     120   1264
# 2     105   1184
# 3     122   1166
# 4  835017   1048
# 5     330   1032
# 6   75709   1026
# 7     808   1022
# 8     809   1014
# 9    9799   1006

# %%
tmdb_counts
# Out:
#           tmdb_id  count
# 0             121   1276
# 1             120   1264
# 2             105   1184
# 3             122   1166
# 4          835017   1048
# ...           ...    ...
# 4223816  25975123      2
# 4223817  24662709      2
# 4223818  24653624      2
# 4223819  24638755      2
# 4223820  24790534      2
#
# [4223821 rows x 2 columns]
