# %%
import os
import firebase_admin
from firebase_admin import credentials, firestore
import vertexai
from vertexai.language_models import TextEmbeddingModel
from google.cloud import storage
import json
import time
from dotenv import load_dotenv

# %%
# uploading the environment variables and get the API key
load_dotenv()
AWS_ACCESS_KEY = os.getenv("AWS_ACCESS_KEY")
AWS_SECRET_KEY = os.getenv("AWS_SECRET_KEY")

# Asegurar que Vertex AI use las credenciales correctas
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

BUCKET_NAME = 'embeddings_bucket_backup'
storage_client = storage.Client()
bucket = storage_client.bucket(BUCKET_NAME)

# %%
# Inicialización
cred = credentials.Certificate('../../../bubbo-dfba0-47e395cdcdc7.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

PROJECT_ID = "bubbo-dfba0"
REGION = "us-central1"
MODEL_ID = "text-multilingual-embedding-002"
vertexai.init(project=PROJECT_ID, location=REGION)
model = TextEmbeddingModel.from_pretrained(MODEL_ID)

# %%
def get_text_embedding(texts):
    """Genera embeddings para una lista de textos."""
    try:
        embeddings = model.get_embeddings(texts)
        return [embedding.values for embedding in embeddings]
    except Exception as e:
        print(f"Error al generar embeddings: {e}")
        return None

def process_and_store_embeddings():
    print("Iniciando procesamiento de documentos...")
    input_collection_ref = db.collection('Data_EN')
    docs = input_collection_ref.stream()
    total_docs = 0
    updated_docs = 0
    failed_embeddings = []

    # Cargar IDs existentes del bucket
    existing_ids = set()
    for blob in bucket.list_blobs():
        if blob.name.endswith('.json'):
            try:
                content = blob.download_as_text()
                existing_data = json.loads(content)
                if isinstance(existing_data, list):
                    for item in existing_data:
                        existing_ids.add(item.get('ID'))
                elif isinstance(existing_data, dict):
                    existing_ids.add(existing_data.get('ID'))
            except json.JSONDecodeError:
                print(f"Error al decodificar JSON del blob: {blob.name}")
            except Exception as e:
                print(f"Error al procesar blob {blob.name}: {e}")

    print(f"Se encontraron {len(existing_ids)} IDs existentes en el bucket.")

    batch_size = 25
    text_batch = []
    doc_batch = []

    for doc in docs:
        try:
            data = doc.to_dict()
            text = f"{data.get('CleanTitle', '')} {data.get('Genre', '')} {data.get('Synopsis', '')}".strip()

            if text:
                text_batch.append(text)
                doc_batch.append(doc)

            if len(text_batch) >= batch_size:
                embeddings = get_text_embedding(text_batch)
                if embeddings is None:
                    print(f"Error al obtener embeddings para el batch. Se omite.")
                    failed_embeddings.extend([doc.id for doc in doc_batch])
                    continue

                for i, embedding in enumerate(embeddings):
                    doc = doc_batch[i]
                    embedding_data = {
                        'ID': doc.id,
                        'embedding': embedding
                    }
                    json_data = json.dumps(embedding_data).encode('utf-8')
                    blob_name = f"{doc.id}.json"

                    if doc.id not in existing_ids:
                        blob = bucket.blob(blob_name)
                        blob.upload_from_string(json_data, content_type='application/json')
                        total_docs += 1
                        updated_docs += 1
                        print(f"Procesado {total_docs}: {doc.id} (Nuevo) -> {text_batch[i][:30]}...")

                    elif doc.id in existing_ids:
                        blob = bucket.blob(blob_name)
                        blob.upload_from_string(json_data, content_type='application/json')
                        total_docs += 1
                        print(f"Procesado {total_docs}: {doc.id} (Actualizado) -> {text_batch[i][:30]}...")

                    if total_docs % 1000 == 0:
                        print(f"Progreso: {total_docs} documentos procesados.")

                # Reiniciar el batch
                text_batch = []
                doc_batch = []
                time.sleep(2)  # Esperar 1 segundo

        except Exception as e:
            print(f"Error al procesar documento {doc.id}: {e}")
            failed_embeddings.append(doc.id)

    # Procesar el último batch (si no está vacío)
    if text_batch:
        embeddings = get_text_embedding(text_batch)
        if embeddings is None:
            print(f"Error al obtener embeddings para el último batch. Se omite.")
            failed_embeddings.extend([doc.id for doc in doc_batch])
        else:
            for i, embedding in enumerate(embeddings):
                doc = doc_batch[i]
                embedding_data = {
                    'ID': doc.id,
                    'embedding': embedding
                }
                json_data = json.dumps(embedding_data).encode('utf-8')
                blob_name = f"{doc.id}.json"

                if doc.id not in existing_ids:
                    blob = bucket.blob(blob_name)
                    blob.upload_from_string(json_data, content_type='application/json')
                    total_docs += 1
                    updated_docs += 1
                    print(f"Procesado {total_docs}: {doc.id} (Nuevo) -> {text_batch[i][:30]}...")

                elif doc.id in existing_ids:
                    blob = bucket.blob(blob_name)
                    blob.upload_from_string(json_data, content_type='application/json')
                    total_docs += 1
                    print(f"Procesado {total_docs}: {doc.id} (Actualizado) -> {text_batch[i][:30]}...")

                if total_docs % 1000 == 0:
                    print(f"Progreso: {total_docs} documentos procesados.")

    # Guardar los IDs de los embeddings fallidos
    if failed_embeddings:
        with open("failed_embeddings.json", "w") as f:
            json.dump(failed_embeddings, f, indent=4)
        print(f"Se encontraron {len(failed_embeddings)} embeddings fallidos. IDs guardados en failed_embeddings.json")

    print(f"Finalizado. Total de documentos procesados: {total_docs}. Documentos Nuevos o actualizados: {updated_docs}")

process_and_store_embeddings()
# Out:
# Iniciando procesamiento de documentos...
# Se encontraron 3200 IDs existentes en el bucket.
# Procesado 1: 10 (Actualizado) -> All in Good Faith Comedy This ...
# Procesado 2: 100 (Actualizado) -> Lock, Stock and Two Smoking Ba...
# Procesado 3: 1000000 (Actualizado) -> Women's toilets Documentary Th...
# Procesado 4: 10000017 (Actualizado) -> Her Deadly Boyfriend Drama; Su...
# Procesado 5: 10000020 (Actualizado) -> Godspeed, The Poles! Documenta...
# Procesado 6: 1000004 (Actualizado) -> Purple Beatz Drama; Romance Sa...
# Procesado 7: 10000042 (Actualizado) -> Flying Fortress: History of th...
# Procesado 8: 10000064 (Actualizado) -> Bisping Sport After a tumultuo...
# Procesado 9: 1000007 (Actualizado) -> Kyle Brownrigg: Introducing Ly...
# Procesado 10: 10000071 (Actualizado) -> Life in Long Beach Documentary...
# Procesado 11: 1000008 (Actualizado) -> The DeAnne Smith EXperience Co...
# Procesado 12: 10000120 (Actualizado) -> Night of the Falling Stars Fan...
# Procesado 13: 10000125 (Actualizado) -> The Conference Drama On Januar...
# Procesado 14: 10000187 (Actualizado) -> Irreplaceable Drama Aryat, a d...
# Procesado 15: 100002 (Actualizado) -> Twenties ‪Drama‬ Twenties cent...
# Procesado 16: 10000231 (Actualizado) -> You Can Never Go Home Again Dr...
# Procesado 17: 10000298 (Actualizado) -> Extra Class 2+ Comedy Ralph an...
# Procesado 18: 10000299 (Actualizado) -> The Hero's Journey to the Thir...
# Procesado 19: 10000349 (Actualizado) -> Keep me company Mystery Silvia...
# Procesado 20: 10000357 (Actualizado) -> Built Beautiful: An Architectu...
# Procesado 21: 10000368 (Actualizado) -> Finding Uranus Comedy Original...
# Procesado 22: 10000498 (Actualizado) -> House with Garden Movies; Shor...
# Procesado 23: 100005 (Actualizado) -> The Funny Dance Show Reality, ...
# Procesado 24: 10000514 (Actualizado) -> Blob Blob Fish Documentary Thr...
# Procesado 25: 10000517 (Actualizado) -> Me Against You: The Movie - Th...
# Procesado 26: 10000530 (Actualizado) -> Lit Drama Two DJs strive to ri...
# Procesado 27: 10000558 (Actualizado) -> Behind the Headlines Documenta...
# Procesado 28: 1000061 (Actualizado) -> Barbès, Little Algeria Comedy,...
# Procesado 29: 10000653 (Actualizado) -> In Jesus Name Drama When a fam...
# Procesado 30: 10000664 (Actualizado) -> She dances in her dreams Drama...
# Procesado 31: 10000686 (Actualizado) -> Fly So Far Documentary As stat...
# Procesado 32: 1000075 (Actualizado) -> The Price of Money - A Largo W...
# Procesado 33: 10000763 (Actualizado) -> The Spot 313 Comedy; Crime Whi...
# Procesado 34: 10000788 (Actualizado) -> 7 Days With You Romance The Du...
# Procesado 35: 1000079 (Actualizado) -> Why are you smiling? Comedy, D...
# Procesado 36: 10000794 (Actualizado) -> The Horror of Making My Film D...
# Procesado 37: 10000836 (Actualizado) -> Zołza Comedy Anna Sobańska (Ma...
# Procesado 38: 10000838 (Actualizado) -> The Rock Table Documentary An ...
# Procesado 39: 10000864 (Actualizado) -> Noryang: Deadly Sea Drama; His...
# Procesado 40: 100009 (Actualizado) -> DevilDolls Horror Padlock the ...
# Procesado 41: 10000914 (Actualizado) -> The Hole in the Fence Drama; S...
# Procesado 42: 10000925 (Actualizado) -> Route 24 Drama In the nation o...
# Procesado 43: 1000094 (Actualizado) -> The clan Comedy Fred, Achille,...
# Procesado 44: 1000095 (Actualizado) -> Lanka Drama Ram, a convict, st...
# Procesado 45: 10000961 (Actualizado) -> In the Sun Documentary In the ...
# Procesado 46: 10000963 (Actualizado) -> A life of crime 1984-2020 Docu...
# Procesado 47: 10000966 (Actualizado) -> Trenches Documentary On the fr...
# Procesado 48: 10000979 (Actualizado) -> Republic of Silence Documentar...
# Procesado 49: 10000986 (Actualizado) -> De André#De André - Story of a...
# Procesado 50: 10000995 (Actualizado) -> My Wunderkammern Documentary I...
# Procesado 51: 10000998 (Actualizado) -> Ezio Bosso: The things that re...
# Procesado 52: 10001 (Actualizado) -> The young Einstein Comedy Albe...
# Procesado 53: 100010 (Actualizado) -> Flight Command Romance; Drama ...
# Procesado 54: 10001007 (Actualizado) -> Stoves Inside Documentary This...
# Procesado 55: 1000108 (Actualizado) -> The little blond boy from the ...
# Procesado 56: 10001087 (Actualizado) -> Noo kids; international; carto...
# Procesado 57: 1000111 (Actualizado) -> One More Jungle Drama; Romance...
# Procesado 58: 100012 (Actualizado) -> Food Lore Drama FOOD LORE is a...
# Procesado 59: 10001218 (Actualizado) -> Carlos Ghosn - The Last Flight...
# Procesado 60: 10001263 (Actualizado) -> Bad Signal: The Series Drama T...
# Procesado 61: 1000127 (Actualizado) -> In his image Drama Fragments o...
# Procesado 62: 10001287 (Actualizado) -> Dark Chronicles ‪Horror‬ On a ...
# Procesado 63: 10001291 (Actualizado) -> Lioness Drama In this South Af...
# Procesado 64: 10001311 (Actualizado) -> My Weapon Was the Law Action; ...
# Procesado 65: 10001322 (Actualizado) -> Bitterbrush ‪Action/Adventure‬...
# Procesado 66: 10001332 (Actualizado) -> A Soldier's Secret Drama After...
# Procesado 67: 10001346 (Actualizado) -> Idhayathai Thirudathey Romance...
# Procesado 68: 10001411 (Actualizado) -> Tune Into the Future ‪Document...
# Procesado 69: 1000143 (Actualizado) -> My share of Gaul Comedy Intend...
# Procesado 70: 10001431 (Actualizado) -> The Breath of the Sea Document...
# Procesado 71: 10001439 (Actualizado) -> Zinder Documentary Zinder is a...
# Procesado 72: 10001460 (Actualizado) -> Such a cloudy sky Documentary ...
# Procesado 73: 10001462 (Actualizado) -> Tonsüchtig: The Vienna Symphon...
# Procesado 74: 10001483 (Actualizado) -> Oh, It Hertz Documentary The m...
# Procesado 75: 10001518 (Actualizado) -> The Gig is Up Documentary A ve...
# Procesado 76: 10001519 (Actualizado) -> Gabi, Between Ages 8 and 13 In...
# Procesado 77: 10001564 (Actualizado) -> Pharma Bro Documentary The sto...
# Procesado 78: 10001566 (Actualizado) -> Cold Drama It is the Christmas...
# Procesado 79: 10001593 (Actualizado) -> Fierce Wolf Drama Detective Al...
# Procesado 80: 10001599 (Actualizado) -> Business of Betrayal Drama Whe...
# Procesado 81: 10001619 (Actualizado) -> A Drunk Scorpion Will Sting It...
# Procesado 82: 10001623 (Actualizado) -> Indigo Love Drama "I remember ...
# Procesado 83: 10001626 (Actualizado) -> You routes Drama Héctor Fáver ...
# Procesado 84: 10001676 (Actualizado) -> 100UP Documentary In 100UP, di...
# Procesado 85: 10001679 (Actualizado) -> Muranow Stories Documentary Th...
# Procesado 86: 1000172 (Actualizado) -> The Damned Don't Cry Drama A C...
# Procesado 87: 1000173 (Actualizado) -> The shadow of evil Horror In t...
# Procesado 88: 10001782 (Actualizado) -> Travel somewhere Documentary A...
# Procesado 89: 10001798 (Actualizado) -> Queen Of The Beach Documentary...
# Procesado 90: 10001813 (Actualizado) -> Finland - Summer on the Lake D...
# Procesado 91: 10001821 (Actualizado) -> Mr. Birthday Drama While worki...
# Procesado 92: 10001843 (Actualizado) -> 75 Grad West Science Fiction F...
# Procesado 93: 10001878 (Actualizado) -> The Opps Drama Ain't no rules ...
# Procesado 94: 100019 (Actualizado) -> Yo-kai Watch! anime The hugely...
# Procesado 95: 10001901 (Actualizado) -> Dear compatriots Drama King Jo...
# Procesado 96: 10001913 (Actualizado) -> Sex and revolution Documentary...
# Procesado 97: 10001923 (Actualizado) -> A Hard Problem Drama Ian clean...
# Procesado 98: 1000194 (Actualizado) -> The Thieves: The true story of...
# Procesado 99: 1000197 (Actualizado) -> The Hidden Fox Drama Watch the...
# Procesado 100: 10002029 (Actualizado) -> The Disappearance of Mrs. Wu D...
# Procesado 101: 10002035 (Actualizado) -> The Race To Save the World Doc...
# Procesado 102: 10002045 (Actualizado) -> Under fire Documentary Under F...
# Procesado 103: 10002055 (Actualizado) -> 15 Minutes Of Shame Documentar...
# Procesado 104: 10002057 (Actualizado) -> A Bolu Music; Documentary Thro...
# Procesado 105: 10002070 (Actualizado) -> calm Drama Lara looks after he...
# Procesado 106: 10002082 (Actualizado) -> Coo Horror A young mother (Oon...
# Procesado 107: 10002086 (Actualizado) -> Word Drama The film follows th...
# Procesado 108: 10002104 (Actualizado) -> My last adventure Suspense Cór...
# Procesado 109: 10002147 (Actualizado) -> Shadow and the Poet Musical In...
# Procesado 110: 10002148 (Actualizado) -> 100 Millions Swimming Sport Th...
# Procesado 111: 10002149 (Actualizado) -> A la puta strasse. 2nd act Doc...
# Procesado 112: 10002160 (Actualizado) -> Confluence: Value in times of ...
# Procesado 113: 10002180 (Actualizado) -> The Rifleman Drama 1915. After...
# Procesado 114: 10002182 (Actualizado) -> Yachimun Drama The real-life s...
# Procesado 115: 1000219 (Actualizado) -> Mom, don't let me fall asleep ...
# Procesado 116: 100022 (Actualizado) -> Mawson - Life and Death in Ant...
# Procesado 117: 1000220 (Actualizado) -> Things are like this. Drama; R...
# Procesado 118: 1000221 (Actualizado) -> #LookAtMe Drama A teenage Yout...
# Procesado 119: 10002231 (Actualizado) -> Boyfriends of Christmas Past R...
# Procesado 120: 10002236 (Actualizado) -> Christmas Sail Drama; Romance ...
# Procesado 121: 10002239 (Actualizado) -> A Christmas Treasure Drama; Ro...
# Procesado 122: 10002240 (Actualizado) -> All on stage at Christmas Roma...
# Procesado 123: 10002278 (Actualizado) -> The Truth About Santa Claus Ch...
# Procesado 124: 10002299 (Actualizado) -> Exland Short Between majestic ...
# Procesado 125: 100023 (Actualizado) -> Death and The Compass Drama, A...
# Procesado 126: 10002323 (Actualizado) -> Throwing a knife into the fire...
# Procesado 127: 10002349 (Actualizado) -> More than I deserve Drama Tama...
# Procesado 128: 10002350 (Actualizado) -> The House On Fin Street Drama ...
# Procesado 129: 10002354 (Actualizado) -> Wild Roads Drama On a cross-co...
# Procesado 130: 10002357 (Actualizado) -> ONLY ONCE Drama Laura, a psych...
# Procesado 131: 10002358 (Actualizado) -> Rebel Objects Suspense A filmm...
# Procesado 132: 1000238 (Actualizado) -> Magic in Mount Holly Romance A...
# Procesado 133: 100024 (Actualizado) -> Bloodwork Horror, Thriller In ...
# Procesado 134: 10002411 (Actualizado) -> Ring Wandering Drama Kusasuke,...
# Procesado 135: 10002412 (Actualizado) -> Wuhan Wuhan Documentary In Feb...
# Procesado 136: 10002416 (Actualizado) -> Toubab Comedy After his releas...
# Procesado 137: 10002427 (Actualizado) -> Luana's oath Drama A powerful ...
# Procesado 138: 10002429 (Actualizado) -> Intelligent Immortality War Do...
# Procesado 139: 10002466 (Actualizado) -> Life in WWII Britain Documenta...
# Procesado 140: 1000249 (Actualizado) -> Cutting Corners Drama Confront...
# Procesado 141: 100025 (Actualizado) -> The little Colonel Family; Mus...
# Procesado 142: 10002512 (Actualizado) -> Tango with Putin Documentary N...
# Procesado 143: 10002515 (Actualizado) -> Colonia Dignidad: A German sec...
# Procesado 144: 10002518 (Actualizado) -> Time of Impatience Drama Unrul...
# Procesado 145: 10002537 (Actualizado) -> Night Stone Drama; Fantasy Sin...
# Procesado 146: 10002560 (Actualizado) -> Hell or Clean Water ‪Documenta...
# Procesado 147: 10002570 (Actualizado) -> Mexican Moon Drama The drug ca...
# Procesado 148: 10002576 (Actualizado) -> Cupids on Beacon Street Romanc...
# Procesado 149: 10002587 (Actualizado) -> Dawn in Calcutta Documentary; ...
# Procesado 150: 10002608 (Actualizado) -> The green sea Documentary Mare...
# Procesado 151: 1000262 (Actualizado) -> I Want Out Children; Drama I W...
# Procesado 152: 1000266 (Actualizado) -> Secrets of the Sasquatch Docum...
# Procesado 153: 10002667 (Actualizado) -> Be born Animation Roberto Vall...
# Procesado 154: 10002670 (Actualizado) -> Sea Dragon Drama A young fossi...
# Procesado 155: 10002691 (Actualizado) -> Dark Cycle Science Fiction; Su...
# Procesado 156: 100027 (Actualizado) -> The Books of John LGBTQ Frank ...
# Procesado 157: 10002750 (Actualizado) -> When You Are Gone Horror; Susp...
# Procesado 158: 10002760 (Actualizado) -> The Noise of Engines Drama Cus...
# Procesado 159: 10002767 (Actualizado) -> Hilda's Vacation Drama An inti...
# Procesado 160: 10002780 (Actualizado) -> Censor of Dreams Fantasy; Horr...
# Procesado 161: 10002786 (Actualizado) -> The Seine's Tears Documentary ...
# Procesado 162: 10002791 (Actualizado) -> The atom and us Documentary; D...
# Procesado 163: 100028 (Actualizado) -> Tornado: Devil's Wind Action; ...
# Procesado 164: 10002815 (Actualizado) -> Swimsuit Drama Samah attempts ...
# Procesado 165: 10002849 (Actualizado) -> An Enchanted Christmas Adventu...
# Procesado 166: 10002850 (Actualizado) -> The Halloween Mystery Adventur...
# Procesado 167: 10002874 (Actualizado) -> Lonely Hearts Club Drama Karla...
# Procesado 168: 1000292 (Actualizado) -> Necroheritage Comedy Three bro...
# Procesado 169: 10002937 (Actualizado) -> Trumpets in the Sky Drama; Sho...
# Procesado 170: 10002980 (Actualizado) -> Japan Sinks - Man of Hope Dram...
# Procesado 171: 10003006 (Actualizado) -> Khmer Rouge, a simple question...
# Procesado 172: 10003030 (Actualizado) -> Corona movie club Documentary ...
# Procesado 173: 10003043 (Actualizado) -> Allseasons Documentary Kitesur...
# Procesado 174: 10003091 (Actualizado) -> Do not commit adultery and do ...
# Procesado 175: 100031 (Actualizado) -> Born Mucky: Life on the Farm D...
# Procesado 176: 10003122 (Actualizado) -> The last tape from Bosnia Docu...
# Procesado 177: 10003142 (Actualizado) -> In truth: In another life Crim...
# Procesado 178: 10003146 (Actualizado) -> A Holiday from Mourning Drama ...
# Procesado 179: 10003171 (Actualizado) -> I'm Not Him Drama A man's ques...
# Procesado 180: 10003190 (Actualizado) -> Chilangolandia Comedy Living i...
# Procesado 181: 100032 (Actualizado) -> Mayil Peelikavu Romance When K...
# Procesado 182: 10003218 (Actualizado) -> Clouds Are Not Spheres Documen...
# Procesado 183: 10003219 (Actualizado) -> Angeliena Comedy After a strin...
# Procesado 184: 10003220 (Actualizado) -> Movie version free! Men's Swim...
# Procesado 185: 10003222 (Actualizado) -> Our Nature Documentary Shot ov...
# Procesado 186: 10003224 (Actualizado) -> Multidimensional Indie A journ...
# Procesado 187: 10003243 (Actualizado) -> Strix Horror In the cursed mon...
# Procesado 188: 10003272 (Actualizado) -> Growing Horror Ewa is training...
# Procesado 189: 10003273 (Actualizado) -> The Hunt for Planet B Document...
# Procesado 190: 10003282 (Actualizado) -> Anchorage Drama; Suspense; Ind...
# Procesado 191: 10003286 (Actualizado) -> Kendra and Beth Drama A woman ...
# Procesado 192: 10003287 (Actualizado) -> To set down Drama Wallflower L...
# Procesado 193: 10003303 (Actualizado) -> Shameful wife sharing Plot Whe...
# Procesado 194: 10003336 (Actualizado) -> A Portrait on the Search for H...
# Procesado 195: 10003344 (Actualizado) -> Brimstone Incorporated Horror ...
# Procesado 196: 10003348 (Actualizado) -> Beautiful wife's friend Drama ...
# Procesado 197: 10003351 (Actualizado) -> Sepia Romance Sepia is a tale ...
# Procesado 198: 10003371 (Actualizado) -> Straitjacket Suspense After ac...
# Procesado 199: 10003372 (Actualizado) -> When We Die at Night Science F...
# Procesado 200: 10003376 (Actualizado) -> Beautiful soul Drama Gioia is ...
# Procesado 201: 10003388 (Actualizado) -> Bottom Feeders Comedy A slacke...
# Procesado 202: 10003391 (Actualizado) -> What If? Ehud Barak on War and...
# Procesado 203: 10003397 (Actualizado) -> Magic City Hustle Documentary ...
# Procesado 204: 100034 (Actualizado) -> Cash Calls Hell Drama Facing t...
# Procesado 205: 10003411 (Actualizado) -> Will Weird Town Compensate? Th...
# Procesado 206: 10003412 (Actualizado) -> Bad Attitude: The Art of Spain...
# Procesado 207: 10003418 (Actualizado) -> Citizen Ashe Sport From acclai...
# Procesado 208: 10003446 (Actualizado) -> A Crime On The Bayou Suspense ...
# Procesado 209: 10003448 (Actualizado) -> The Neutral Ground Documentary...
# Procesado 210: 10003449 (Actualizado) -> BITCHIN': The Sound and Fury o...
# Procesado 211: 10003451 (Actualizado) -> Missing in Brooks County Docum...
# Procesado 212: 10003452 (Actualizado) -> KEVIN GARNETT: Anything Is Pos...
# Procesado 213: 10003468 (Actualizado) -> A StoryBots Space Adventure An...
# Procesado 214: 100035 (Actualizado) -> Crime for newlyweds Comedy A p...
# Procesado 215: 10003504 (Actualizado) -> The Farm Hand Suspense Andrew ...
# Procesado 216: 10003524 (Actualizado) -> Last Night in Rozzie Drama; In...
# Procesado 217: 10003539 (Actualizado) -> Balloon and the wonders of the...
# Procesado 218: 10003543 (Actualizado) -> South Park: Pos-Covid Comedy S...
# Procesado 219: 10003588 (Actualizado) -> A Dickens of a Holiday! Drama;...
# Procesado 220: 10003592 (Actualizado) -> Like a Rolling Stone: The Life...
# Procesado 221: 10003596 (Actualizado) -> The infinite vastness of the s...
# Procesado 222: 10003597 (Actualizado) -> The Story Won't Die Documentar...
# Procesado 223: 10003601 (Actualizado) -> Fast Charlie Suspense When his...
# Procesado 224: 10003602 (Actualizado) -> A Choice of Weapons: Inspired ...
# Procesado 225: 10003640 (Actualizado) -> Guy Ritchie's: The Covenant Ac...
# Procesado 226: 10003646 (Actualizado) -> My Childhood, My Country, 20 Y...
# Procesado 227: 10003669 (Actualizado) -> Bright Green Lies Documentary ...
# Procesado 228: 10003670 (Actualizado) -> Innermost Drama Laura closes p...
# Procesado 229: 10003688 (Actualizado) -> Before I'm Dead Suspense The l...
# Procesado 230: 10003697 (Actualizado) -> Drifting Snow Drama A car acci...
# Procesado 231: 10003706 (Actualizado) -> Hotel Blue Drama Jackie Sands,...
# Procesado 232: 10003732 (Actualizado) -> Zoey's Extraordinary Christmas...
# Procesado 233: 10003751 (Actualizado) -> Ice Cream Children Set in 1990...
# Procesado 234: 10003777 (Actualizado) -> Sediments Documentary An emoti...
# Procesado 235: 100038 (Actualizado) -> The Lovers of the Nile Adventu...
# Procesado 236: 10003862 (Actualizado) -> Spreadsheet Comedy Lauren is a...
# Procesado 237: 10003885 (Actualizado) -> I'll Hide You Seek Drama Alice...
# Procesado 238: 100039 (Actualizado) -> Come to Germany, Pepe! Comedy ...
# Procesado 239: 10003932 (Actualizado) -> wall log Xiao Ji and Xiao Kai,...
# Procesado 240: 10003991 (Actualizado) -> The Last White Man Drama; Susp...
# Procesado 241: 10004 (Actualizado) -> Stephen King's Desperation Dra...
# Procesado 242: 100040 (Actualizado) -> The moon is worth a million Co...
# Procesado 243: 10004088 (Actualizado) -> Music to Madness: The Story of...
# Procesado 244: 10004110 (Actualizado) -> We remain friends Comedy Roman...
# Procesado 245: 10004146 (Actualizado) -> A Beautiful Curse Drama; Roman...
# Procesado 246: 10004156 (Actualizado) -> Adieu Godard Drama A small Ind...
# Procesado 247: 100042 (Actualizado) -> Dumb and Dumber 2 Comedy; Come...
# Procesado 248: 10004232 (Actualizado) -> April's Last Memories Drama; R...
# Procesado 249: 10004249 (Actualizado) -> Underwater magic Children The ...
# Procesado 250: 10004262 (Actualizado) -> The Shepherd and the Guerrilla...
# Procesado 251: 10004277 (Actualizado) -> The Beatles and India Document...
# Procesado 252: 10004279 (Actualizado) -> You must have imagined it Crim...
# Procesado 253: 10004289 (Actualizado) -> I Am Belmaya Documentary In th...
# Procesado 254: 100043 (Actualizado) -> The Black Bow Truck 2 Comedy, ...
# Procesado 255: 10004300 (Actualizado) -> tribe Drama Two soldiers from ...
# Procesado 256: 10004307 (Actualizado) -> The Nature of Romance Romance;...
# Procesado 257: 10004316 (Actualizado) -> Songs for a Sloth Drama Maxwel...
# Procesado 258: 10004319 (Actualizado) -> Precious Hair & Beauty Drama D...
# Procesado 259: 10004329 (Actualizado) -> Baltic Case Files: Murder on t...
# Procesado 260: 10004332 (Actualizado) -> The Sound of Violet Drama; Rom...
# Procesado 261: 1000434 (Actualizado) -> My Beast Suspense; Fantasy; Dr...
# Procesado 262: 10004357 (Actualizado) -> Kaimos Drama A 40 year-old wom...
# Procesado 263: 10004358 (Actualizado) -> People You May Know Drama Elev...
# Procesado 264: 100044 (Actualizado) -> Pavitra Bhagya Drama Jugnu liv...
# Procesado 265: 10004439 (Actualizado) -> Girls/Museum Documentary A jou...
# Procesado 266: 10004492 (Actualizado) -> See you in prison, fall in lov...
# Procesado 267: 100045 (Actualizado) -> misguided love Documentary We ...
# Procesado 268: 10004500 (Actualizado) -> Another world Documentary This...
# Procesado 269: 10004506 (Actualizado) -> Saveart Recycling Art Document...
# Procesado 270: 10004508 (Actualizado) -> Life is an endless dance Music...
# Procesado 271: 1000451 (Actualizado) -> Captain Fracassa Children Afte...
# Procesado 272: 10004530 (Actualizado) -> God Brain Documentary God Brai...
# Procesado 273: 10004555 (Actualizado) -> Baja Come Down Drama; Romance ...
# Procesado 274: 10004556 (Actualizado) -> Dive Drama A young woman in Ir...
# Procesado 275: 10004581 (Actualizado) -> The Scrapper Crime Ex-con Jake...
# Procesado 276: 100046 (Actualizado) -> The Giant Mechanical Man Drama...
# Procesado 277: 10004619 (Actualizado) -> The Man Who Went to Heaven Dra...
# Procesado 278: 10004649 (Actualizado) -> Theodosia Children; Children; ...
# Procesado 279: 1000470 (Actualizado) -> Paranormal 2020 Horror; Suspen...
# Procesado 280: 100048 (Actualizado) -> In the Blink of an Eye Drama T...
# Procesado 281: 10004853 (Actualizado) -> Clown's Planet Documentary Clo...
# Procesado 282: 1000486 (Actualizado) -> The Pink Coat Musical; Animati...
# Procesado 283: 100049 (Actualizado) -> The big lie Drama A new film h...
# Procesado 284: 10004934 (Actualizado) -> She Said Drama Two-time Academ...
# Procesado 285: 1000494 (Actualizado) -> Love Punch Sport In the wrecka...
# Procesado 286: 1000497 (Actualizado) -> Psycho Baby LGBTQ; Drama When ...
# Procesado 287: 10005 (Actualizado) -> Enemy Lines 2: Infiltrating No...
# Procesado 288: 100050 (Actualizado) -> Passage to Venezuela Drama Two...
# Procesado 289: 10005035 (Actualizado) -> Nicole Byer: A Big Piece of Be...
# Procesado 290: 10005127 (Actualizado) -> Starved Rock Murders Biography...
# Procesado 291: 10005139 (Actualizado) -> The Brain: The Future of Artif...
# Procesado 292: 1000517 (Actualizado) -> The Paris Gang Suspense Bébé a...
# Procesado 293: 100052 (Actualizado) -> Thursdays, miracle Comedy; Fan...
# Procesado 294: 100053 (Actualizado) -> The Three Stooges Go Around th...
# Procesado 295: 1000532 (Actualizado) -> The Pillar Of Strength History...
# Procesado 296: 1000533 (Actualizado) -> Assi Doesn't Live Here History...
# Procesado 297: 1000534 (Actualizado) -> Tribal Law History; Romance; D...
# Procesado 298: 100054 (Actualizado) -> The First Lesson of True Love ...
# Procesado 299: 1000553 (Actualizado) -> We Bought a Haunted House Susp...
# Procesado 300: 100057 (Actualizado) -> American Animal Indie In this ...
# Procesado 301: 1000575 (Actualizado) -> Shots: Eugenics to Pandemics D...
# Procesado 302: 10005829 (Actualizado) -> Brazen Thriller Mystery writer...
# Procesado 303: 1000583 (Actualizado) -> Col. Billy Bibit, Ram Action A...
# Procesado 304: 100059 (Actualizado) -> BFF. Furry Friends Children Ea...
# Procesado 305: 1000597 (Actualizado) -> The Adventures of Jeff Panaclo...
# Procesado 306: 10006 (Actualizado) -> Wild Seven Action, Crime, Dram...
# Procesado 307: 100061 (Actualizado) -> Son Of A Lion Drama 11 year ol...
# Procesado 308: 1000618 (Actualizado) -> To the north Drama A Filipino ...
# Procesado 309: 1000622 (Actualizado) -> Elvis and the USS Arizona Docu...
# Procesado 310: 1000624 (Actualizado) -> RWBY Volume 3 Horror Vale is b...
# Procesado 311: 1000638 (Actualizado) -> Here Brazza Documentary Antoin...
# Procesado 312: 100064 (Actualizado) -> Star of Cottonland Comedy, Cri...
# Procesado 313: 10006402 (Actualizado) -> Royal Estate Drama Iñaki (79),...
# Procesado 314: 1000643 (Actualizado) -> Going Green Comedy Strengtheni...
# Procesado 315: 1000644 (Actualizado) -> Your sweet face Drama In the s...
# Procesado 316: 1000646 (Actualizado) -> Housewife surveys Drama With S...
# Procesado 317: 1000649 (Actualizado) -> Clandestine Dialogues 2003-200...
# Procesado 318: 100065 (Actualizado) -> Kong: "King of Atlantis" Child...
# Procesado 319: 1000653 (Actualizado) -> Dialogues clandestins Low Life...
# Procesado 320: 1000656 (Actualizado) -> After the Revolution Drama Whe...
# Procesado 321: 1000666 (Actualizado) -> Damn. A Love Song to Sarajevo ...
# Procesado 322: 1000674 (Actualizado) -> Touch of Greatness - A Portrai...
# Procesado 323: 1000678 (Actualizado) -> Black substance Science Fictio...
# Procesado 324: 1000683 (Actualizado) -> shock Drama SHOCK is an intens...
# Procesado 325: 10006836 (Actualizado) -> The girl before Drama Jane dis...
# Procesado 326: 100069 (Actualizado) -> Golf in the Kingdom Drama The ...
# Procesado 327: 1000691 (Actualizado) -> Mermaids don't cry Comedy When...
# Procesado 328: 1000695 (Actualizado) -> Time for some weather Comedy A...
# Procesado 329: 10007 (Actualizado) -> See No Evil: The Fleshhook Sac...
# Procesado 330: 1000702 (Actualizado) -> Empath Comedy The great irony ...
# Procesado 331: 10007036 (Actualizado) -> The Fool of the End Drama An a...
# Procesado 332: 10007057 (Actualizado) -> Vandhaal Sridevi Drama At an a...
# Procesado 333: 100071 (Actualizado) -> Waybuloo Children Waybuloo tra...
# Procesado 334: 1000723 (Actualizado) -> Baby Oopsie 2: Murder Dolls Ho...
# Procesado 335: 1000727 (Actualizado) -> Finding Her Beat LGBTQ For tho...
# Procesado 336: 1000728 (Actualizado) -> Minnesota Mean ‪Documentary‬ "...
# Procesado 337: 10007506 (Actualizado) -> Ideas for Sale Reality Brazili...
# Procesado 338: 100076 (Actualizado) -> Boy, girl, boom! Musical André...
# Procesado 339: 1000780 (Actualizado) -> Bleeding Love Drama In hopes o...
# Procesado 340: 1000786 (Actualizado) -> Palermo Renaissance Documentar...
# Procesado 341: 10007947 (Actualizado) -> Abjuration Drama Fofo, a humbl...
# Procesado 342: 10007962 (Actualizado) -> Velunachi Drama When a young v...
# Procesado 343: 10007973 (Actualizado) -> Watch Paapnaashini Ganga TV Sh...
# Procesado 344: 10008 (Actualizado) -> Appearances Drama Based on the...
# Procesado 345: 100080 (Actualizado) -> The butler Comedy; Romance An ...
# Procesado 346: 100081 (Actualizado) -> Sin of love Drama; Musical A m...
# Procesado 347: 1000836 (Actualizado) -> Shajiadian Grain Station War, ...
# Procesado 348: 10008428 (Actualizado) -> Pablo Picasso and Françoise Gi...
# Procesado 349: 1000862 (Actualizado) -> No waves Drama, Thriller A tea...
# Procesado 350: 1000866 (Actualizado) -> A fanfare Comedy Thibaut is an...
# Procesado 351: 100087 (Actualizado) -> Until money separates us Drama...
# Procesado 352: 1000877 (Actualizado) -> Lacee Drama Sex, power, and be...
# Procesado 353: 100088 (Actualizado) -> Black Gunn Drama A successful ...
# Procesado 354: 1000888 (Actualizado) -> Plastic guns Comedy Léa and Ch...
# Procesado 355: 100089 (Actualizado) -> Nazis at the Center of the Ear...
# Procesado 356: 10009 (Actualizado) -> Brother Bear Children Disney p...
# Procesado 357: 100090 (Actualizado) -> The Darien Gap Drama A lazy co...
# Procesado 358: 10009170 (Actualizado) -> Floating Islands Drama The fil...
# Procesado 359: 100092 (Actualizado) -> HIS: I Didn't Think I Would Fa...
# Procesado 360: 10009245 (Actualizado) -> Life after death, with Tyler H...
# Procesado 361: 1000927 (Actualizado) -> Myrna Diones Story Drama Based...
# Procesado 362: 10009319 (Actualizado) -> Catherine Cohen: What's the tw...
# Procesado 363: 1000939 (Actualizado) -> Pacifico Guevarra: Dillinger O...
# Procesado 364: 1000941 (Actualizado) -> Frivolous Paris Crime In the p...
# Procesado 365: 1000942 (Actualizado) -> Occasionally Crime The team tr...
# Procesado 366: 1000943 (Actualizado) -> Time-Temple-Portrait Crime A m...
# Procesado 367: 1000944 (Actualizado) -> Wake Up! It's Yesterday Crime ...
# Procesado 368: 1000945 (Actualizado) -> The Good, the Bad, & the Ugly ...
# Procesado 369: 1000946 (Actualizado) -> Black Cheerleader Gang Bang 25...
# Procesado 370: 1000947 (Actualizado) -> Straight Boy Crime The murder ...
# Procesado 371: 1000948 (Actualizado) -> A Freaking Wedding! Crime The ...
# Procesado 372: 1000949 (Actualizado) -> Margie & Scott Crime The mummi...
# Procesado 373: 100095 (Actualizado) -> Tournament of Champions Advent...
# Procesado 374: 1000950 (Actualizado) -> Blue Jeans Gang Crime The team...
# Procesado 375: 1000951 (Actualizado) -> Aguirre Crime In the midst of ...
# Procesado 376: 1000952 (Actualizado) -> Mother of Invention Crime A re...
# Procesado 377: 1000953 (Actualizado) -> Nostalgia Crime In the most di...
# Procesado 378: 1000955 (Actualizado) -> Poor man's dinner Drama As he ...
# Procesado 379: 1000965 (Actualizado) -> Juliette in spring Drama Julie...
# Procesado 380: 100098 (Actualizado) -> A ray of light Family; Musical...
# Procesado 381: 10010 (Actualizado) -> Brother Bear 2 Children Animat...
# Procesado 382: 100100 (Actualizado) -> The Return of Chandu Action, F...
# Procesado 383: 1001008 (Actualizado) -> Downwind of the Marquesas Dram...
# Procesado 384: 1001019 (Actualizado) -> A man on the run Drama Rochebr...
# Procesado 385: 1001023 (Actualizado) -> A few days, no more Drama Arth...
# Procesado 386: 1001026 (Actualizado) -> Men's dorm Comedy A Parisian f...
# Procesado 387: 1001028 (Actualizado) -> A Matter of Principle Thriller...
# Procesado 388: 100103 (Actualizado) -> The Show Continues Family A mi...
# Procesado 389: 100104 (Actualizado) -> Blonde arrow Drama The famous ...
# Procesado 390: 100105 (Actualizado) -> Michael Tilson Thomas: The Tho...
# Procesado 391: 1001054 (Actualizado) -> Lazy Girls Animation One year ...
# Procesado 392: 1001055 (Actualizado) -> Pussy Patrol Animation Sinon, ...
# Procesado 393: 1001056 (Actualizado) -> Republic of Herrskog Animation...
# Procesado 394: 1001069 (Actualizado) -> UFO Club Comedy A nerd becomes...
# Procesado 395: 100107 (Actualizado) -> Saving Sirga Journey Into the ...
# Procesado 396: 1001075 (Actualizado) -> Captain Jaylo: Law by law Chil...
# Procesado 397: 1001080 (Actualizado) -> Full to the bone Drama Claire'...
# Procesado 398: 1001083 (Actualizado) -> Meanwhile on Earth Crime Annie...
# Procesado 399: 10010868 (Actualizado) -> Telesma Drama "Filmed in 20 co...
# Procesado 400: 10010870 (Actualizado) -> Pink Series Guinea Pig Drama; ...
# Procesado 401: 10010892 (Actualizado) -> I'm Quiet Drama The story of a...
# Procesado 402: 1001091 (Actualizado) -> Do Something Drama When a Blac...
# Procesado 403: 10011 (Actualizado) -> Abominable Horror A disabled m...
# Procesado 404: 10011025 (Actualizado) -> Crazy Days Documentary With a ...
# Procesado 405: 1001127 (Actualizado) -> The Swedish Sin 1969-2000 Docu...
# Procesado 406: 100113 (Actualizado) -> Counter-Espionage Suspense Lon...
# Procesado 407: 1001145 (Actualizado) -> Double foyer Children Emma and...
# Procesado 408: 100115 (Actualizado) -> Day And Age Documentary Snowbo...
# Procesado 409: 1001151 (Actualizado) -> Big Naturals 59 Drama During t...
# Procesado 410: 100116 (Actualizado) -> Margaret Thatcher: The Iron La...
# Procesado 411: 100117 (Actualizado) -> Bad As I Wanna Be: The Dennis ...
# Procesado 412: 10011854 (Actualizado) -> The Big Cigar Drama Black Pant...
# Procesado 413: 1001196 (Actualizado) -> Spirited Away: Live on Stage C...
# Procesado 414: 100120 (Actualizado) -> The Most Dangerous Animal of A...
# Procesado 415: 100121 (Actualizado) -> Cape Horn Romance; Drama The w...
# Procesado 416: 10012113 (Actualizado) -> Barcelona, ​​before time erase...
# Procesado 417: 100122 (Actualizado) -> The art of dying Horror Nacho,...
# Procesado 418: 1001230 (Actualizado) -> Go! Rainbow Mask vs. the Homel...
# Procesado 419: 1001231 (Actualizado) -> François Villon: The Maverick ...
# Procesado 420: 100124 (Actualizado) -> Edgar Wallace: The Man with th...
# Procesado 421: 1001245 (Actualizado) -> Silver Venus Drama 24-year-old...
# Procesado 422: 1001272 (Actualizado) -> Ward 126 Drama; Suspense A You...
# Procesado 423: 1001274 (Actualizado) -> Night Call Suspense; Indie In ...
# Procesado 424: 1001275 (Actualizado) -> Bootlegging My Way Into Hell D...
# Procesado 425: 10012810 (Actualizado) -> Father And Boy Drama A 12-year...
# Procesado 426: 10012812 (Actualizado) -> The Lane Drama Although tensio...
# Procesado 427: 10012912 (Actualizado) -> Just not giving it your all ye...
# Procesado 428: 1001292 (Actualizado) -> The Ghosts Drama, Mystery Hami...
# Procesado 429: 1001295 (Actualizado) -> 2017 Documentary The 2017 docu...
# Procesado 430: 10013 (Actualizado) -> Peggy Sue Got Married Romance ...
# Procesado 431: 1001311 (Actualizado) -> In the depths of the Seine Hor...
# Procesado 432: 100132 (Actualizado) -> Coming Out to Class Drama Arou...
# Procesado 433: 1001323 (Actualizado) -> Why Wettelen Drama Dimitri Ver...
# Procesado 434: 100134 (Actualizado) -> Warbird Workshop Documentary I...
# Procesado 435: 1001340 (Actualizado) -> Cum In My Mouth Not In My Ass ...
# Procesado 436: 10013603 (Actualizado) -> At War With the Dinosaurs Docu...
# Procesado 437: 1001368 (Actualizado) -> I love life Drama Mira is a yo...
# Procesado 438: 100138 (Actualizado) -> CAPiTA: Defenders of Awesome D...
# Procesado 439: 1001380 (Actualizado) -> Earth... Blood... Drama; Adven...
# Procesado 440: 10013804 (Actualizado) -> Purse Horror Owning an evil pu...
# Procesado 441: 100139 (Actualizado) -> Jeff Garlin: Young And Handsom...
# Procesado 442: 10014 (Actualizado) -> Nightmare on Elm Street 2 Horr...
# Procesado 443: 100140 (Actualizado) -> The blue planet Documentary Th...
# Procesado 444: 10014012 (Actualizado) -> He Played Me Drama A woman try...
# Procesado 445: 1001402 (Actualizado) -> Horrible Drama, Comedy After d...
# Procesado 446: 1001403 (Actualizado) -> Like magic Comedy, Drama Since...
# Procesado 447: 100141 (Actualizado) -> Australis: An Antarctic Ski Od...
# Procesado 448: 1001414 (Actualizado) -> Fear Street: Prom Queen Comedy...
# Procesado 449: 1001416 (Actualizado) -> Teeny Black Chicks Trying Whit...
# Procesado 450: 1001417 (Actualizado) -> So Long, Marianne Comedy Molly...
# Procesado 451: 1001418 (Actualizado) -> Mouth Cava Terra Drama A 10-ye...
# Procesado 452: 10014188 (Actualizado) -> Nina's Formula 1 Documentary N...
# Procesado 453: 100142 (Actualizado) -> Nick Di Paolo: Raw Nerve Indie...
# Procesado 454: 1001421 (Actualizado) -> Unburial Comedy Molly notices ...
# Procesado 455: 1001422 (Actualizado) -> WAYS OF SEEING Comedy Mike and...
# Procesado 456: 1001423 (Actualizado) -> Kotpad Weaving: The Story of a...
# Procesado 457: 1001426 (Actualizado) -> My House Was Hijacked By A Che...
# Procesado 458: 1001427 (Actualizado) -> Seeking Cetaceans in Scotland ...
# Procesado 459: 1001428 (Actualizado) -> Anatole Latuile Comedy Molly, ...
# Procesado 460: 1001429 (Actualizado) -> Side Chick Comedy Carl is shoc...
# Procesado 461: 1001430 (Actualizado) -> Information Theory Comedy Mike...
# Procesado 462: 1001431 (Actualizado) -> Lies My Sister Told Me Drama; ...
# Procesado 463: 1001432 (Actualizado) -> Like fire Drama A choral film ...
# Procesado 464: 1001433 (Actualizado) -> Intestines from Space Comedy A...
# Procesado 465: 1001434 (Actualizado) -> My life my face Comedy Barberi...
# Procesado 466: 1001435 (Actualizado) -> Life before me Documentary Dur...
# Procesado 467: 100144 (Actualizado) -> 1895 Drama; War After the defe...
# Procesado 468: 1001440 (Actualizado) -> Full stop Documentary; Drama T...
# Procesado 469: 1001456 (Actualizado) -> Survival in Brandenburg Indie ...
# Procesado 470: 1001465 (Actualizado) -> Double Emparazada 2 comedy Ten...
# Procesado 471: 10014660 (Actualizado) -> Hold My Hand Romance; Comedy M...
# Procesado 472: 10014872 (Actualizado) -> Horrible Ghost Doll comedy It’...
# Procesado 473: 100149 (Actualizado) -> Frozen City Drama A volatile t...
# Procesado 474: 10014931 (Actualizado) -> Sixteen Syndrome Drama Azuma I...
# Procesado 475: 1001497 (Actualizado) -> Stuck Outside Of Phoenix Histo...
# Procesado 476: 10015 (Actualizado) -> Heartbreak Ridge Drama Clint E...
# Procesado 477: 100150 (Actualizado) -> Wood Work Drama Cavanero tells...
# Procesado 478: 1001503 (Actualizado) -> The Iron Woman Drama Carrie an...
# Procesado 479: 1001504 (Actualizado) -> Queen: Magic Moments Drama Car...
# Procesado 480: 1001507 (Actualizado) -> T H E M Science Fiction, Thril...
# Procesado 481: 100151 (Actualizado) -> Father, please take us back Co...
# Procesado 482: 1001512 (Actualizado) -> A Flower Above the Clouds Dram...
# Procesado 483: 1001513 (Actualizado) -> Fixxxion 3 Comedy Death is on ...
# Procesado 484: 1001514 (Actualizado) -> The Story of William Tell Come...
# Procesado 485: 1001515 (Actualizado) -> CROSBY, STILLS & NASH Live 199...
# Procesado 486: 1001516 (Actualizado) -> Enter the War Comedy In the an...
# Procesado 487: 1001517 (Actualizado) -> Counterpart Comedy Lisa brings...
# Procesado 488: 1001519 (Actualizado) -> THE LAST JUDGMENT Comedy Moe's...
# Procesado 489: 100152 (Actualizado) -> Little Big Men Sport When Kirk...
# Procesado 490: 10015218 (Actualizado) -> Historjá - Stitches for Sápmi ...
# Procesado 491: 10015295 (Actualizado) -> The Dark Heart Drama Follows T...
# Procesado 492: 100153 (Actualizado) -> The glass eye Crime, Thriller ...
# Procesado 493: 10015373 (Actualizado) -> Enchantimals Ocean Kingdom Chi...
# Procesado 494: 100155 (Actualizado) -> Sesame Street: A Magical Hallo...
# Procesado 495: 10015524 (Actualizado) -> David A. Arnold: Not for the f...
# Procesado 496: 1001555 (Actualizado) -> In the Shadow of the Marquise ...
# Procesado 497: 100156 (Actualizado) -> Massive Engineering Mistakes D...
# Procesado 498: 10015647 (Actualizado) -> Asteroid Mining: The New El Do...
# Procesado 499: 10015661 (Actualizado) -> Devilish Plan fear A man kille...
# Procesado 500: 10015858 (Actualizado) -> The Last Movie Stars Documenta...
# Procesado 501: 10015868 (Actualizado) -> Harry & Meghan: The Price of F...
# Procesado 502: 10015886 (Actualizado) -> Under The Rainbow Drama Set in...
# Procesado 503: 100159 (Actualizado) -> Hellish Journey to Golden City...
# Procesado 504: 1001595 (Actualizado) -> Life After Documentary Ghost h...
# Procesado 505: 1001598 (Actualizado) -> Go Chase Yourself Suspense Mar...
# Procesado 506: 1001599 (Actualizado) -> Orders From Above Drama Fiftee...
# Procesado 507: 10016 (Actualizado) -> Ghost of Mars Horror The year ...
# Procesado 508: 100160 (Actualizado) -> I'm in Paris Animation, Comedy...
# Procesado 509: 1001603 (Actualizado) -> The Holly Documentary In a Bla...
# Procesado 510: 100161 (Actualizado) -> Flattery Comedy; Musical A mus...
# Procesado 511: 10016158 (Actualizado) -> Get Home Safe Short Maya is a ...
# Procesado 512: 100163 (Actualizado) -> The phenomenon Comedy A funny ...
# Procesado 513: 1001632 (Actualizado) -> Krishnamma Drama; Action The l...
# Procesado 514: 1001636 (Actualizado) -> In the Month of July Drama A f...
# Procesado 515: 100165 (Actualizado) -> The servants Animation, Comedy...
# Procesado 516: 1001675 (Actualizado) -> It's Not a Wolf Horror, Comedy...
# Procesado 517: 100168 (Actualizado) -> Love below zero Comedy A delig...
# Procesado 518: 1001684 (Actualizado) -> Niki Drama Paris 1952, Niki ha...
# Procesado 519: 1001696 (Actualizado) -> Witching Hour 2 Horror A clock...
# Procesado 520: 10017 (Actualizado) -> The Boss Baby Part 2: Family B...
# Procesado 521: 10017019 (Actualizado) -> Naulakha Drama Sisters in law ...
# Procesado 522: 1001713 (Actualizado) -> The Legend Of Enveloped Demons...
# Procesado 523: 1001714 (Actualizado) -> Green Bullet: The Legend of th...
# Procesado 524: 1001717 (Actualizado) -> Ricardo Quevedo: Tomorrow Will...
# Procesado 525: 1001721 (Actualizado) -> Miz Cracker: Here I Stand ‪Oth...
# Procesado 526: 1001724 (Actualizado) -> Drummies Documentary, Drama In...
# Procesado 527: 10017566 (Actualizado) -> Prince Harry: Joker In The Pac...
# Procesado 528: 100176 (Actualizado) -> Gentlemen in White Vests Comed...
# Procesado 529: 10017601 (Actualizado) -> Ivy + Bean: Doomed to Dance Co...
# Procesado 530: 10017602 (Actualizado) -> Ivy + Bean: The Ghost That Had...
# Procesado 531: 10017730 (Actualizado) -> St. Gabriel: Sins of the Past ...
# Procesado 532: 1001776 (Actualizado) -> Little Ukraine Drama A Jewish ...
# Procesado 533: 10017810 (Actualizado) -> Just Ask for It Drama Macy and...
# Procesado 534: 10017827 (Actualizado) -> Royal Weddings Through The Yea...
# Procesado 535: 1001783 (Actualizado) -> Death in LaRoy, Texas Comedy; ...
# Procesado 536: 100179 (Actualizado) -> London In The Raw Documentary ...
# Procesado 537: 10017903 (Actualizado) -> Brazilian Theater Companies Do...
# Procesado 538: 10018 (Actualizado) -> Life is a construction site Ro...
# Procesado 539: 10018080 (Actualizado) -> The sins of our mother Documen...
# Procesado 540: 1001819 (Actualizado) -> Death Squad Animation A myster...
# Procesado 541: 10018225 (Actualizado) -> Tishnagi Dil Ki Romance; Drama...
# Procesado 542: 1001825 (Actualizado) -> Pinpoint Adventure After disco...
# Procesado 543: 100183 (Actualizado) -> Outpost - Black Sun Action, Ho...
# Procesado 544: 1001833 (Actualizado) -> At the end of the night Drama ...
# Procesado 545: 1001847 (Actualizado) -> Fantastic Britain Suspense; Dr...
# Procesado 546: 1001848 (Actualizado) -> Duty of Care: The Climate Tria...
# Procesado 547: 10018527 (Actualizado) -> Harry & Meghan: A New Life In ...
# Procesado 548: 100187 (Actualizado) -> Downhill Willie Comedy In this...
# Procesado 549: 1001872 (Actualizado) -> California Shark Hotspots Docu...
# Procesado 550: 10018746 (Actualizado) -> Abhi Tailor Drama Traditional,...
# Procesado 551: 1001875 (Actualizado) -> Travelers: Lost in Time Drama,...
# Procesado 552: 10018906 (Actualizado) -> What's Your Hustle? Sport WHAT...
# Procesado 553: 1001898 (Actualizado) -> Called Drama Kathleen Selchow ...
# Procesado 554: 10019012 (Actualizado) -> Meghan: American Duchess Indie...
# Procesado 555: 10019061 (Actualizado) -> The Brave One Drama A young wo...
# Procesado 556: 10019098 (Actualizado) -> Nachiyarpuram Drama Two famili...
# Procesado 557: 100191 (Actualizado) -> Beyond the Seventh Door Horror...
# Procesado 558: 1001912 (Actualizado) -> The Making of Ms. Marvel Docum...
# Procesado 559: 100192 (Actualizado) -> Destination: Infestation Drama...
# Procesado 560: 100193 (Actualizado) -> Terror Squad Action, Thriller ...
# Procesado 561: 10019484 (Actualizado) -> Prince Philip: Enigma Indie Fr...
# Procesado 562: 100195 (Actualizado) -> Healing Hearts Comedy Senior M...
# Procesado 563: 100196 (Actualizado) -> Julian Monday Drama Mysterious...
# Procesado 564: 10019625 (Actualizado) -> Yu-Gi-Oh! GO RUSH!! Anime Twin...
# Procesado 565: 1001967 (Actualizado) -> The Narco Stores Crime Drug de...
# Procesado 566: 10019682 (Actualizado) -> Will Smith: Prince to King Doc...
# Procesado 567: 1001974 (Actualizado) -> Flood in the Desert Documentar...
# Procesado 568: 1001978 (Actualizado) -> Mayan Orchestra Drama A journe...
# Procesado 569: 100198 (Actualizado) -> Wolf Girls Think Drama The she...
# Procesado 570: 10019878 (Actualizado) -> Who Killed Don Bolles? Documen...
# Procesado 571: 10020 (Actualizado) -> Police Woman Drama Sgt. Suzann...
# Procesado 572: 1002000 (Actualizado) -> The Belgian wave Comedy In the...
# Procesado 573: 10020028 (Actualizado) -> Be Careful What You Ask For Dr...
# Procesado 574: 10020065 (Actualizado) -> Depp VS Heard: All on the Line...
# Procesado 575: 1002013 (Actualizado) -> Dean's Place Comedy, Music Dea...
# Procesado 576: 100203 (Actualizado) -> Sexual Subway Comedy Sexual he...
# Procesado 577: 10020312 (Actualizado) -> The Life and Death of Tupac Sh...
# Procesado 578: 1002044 (Actualizado) -> Unexpected Drama Nessa pursues...
# Procesado 579: 1002045 (Actualizado) -> T Girl Taboo Drama Nessa pursu...
# Procesado 580: 1002046 (Actualizado) -> That Mom Is Stacked Drama Hayd...
# Procesado 581: 1002047 (Actualizado) -> That's the Spirit! Drama Nessa...
# Procesado 582: 1002048 (Actualizado) -> The Length of My Gaze at Night...
# Procesado 583: 1002049 (Actualizado) -> The Ark Drama Shimon Ben-Reuve...
# Procesado 584: 100205 (Actualizado) -> Triumphal March Drama An Itali...
# Procesado 585: 1002054 (Actualizado) -> Ten minutes to midnight Drama ...
# Procesado 586: 100209 (Actualizado) -> Shihad Beautiful Machine Docum...
# Procesado 587: 1002095 (Actualizado) -> 100 Miles to Redemption Docume...
# Procesado 588: 10021 (Actualizado) -> The Secret of My Success Roman...
# Procesado 589: 100211 (Actualizado) -> Hey Sensei, Don't You Know? Do...
# Procesado 590: 1002110 (Actualizado) -> Welcome To The Machine Documen...
# Procesado 591: 1002111 (Actualizado) -> Foot Drama Pê - Movies - Pê, a...
# Procesado 592: 10021144 (Actualizado) -> Bonnie and Lionnie Drama Sofia...
# Procesado 593: 100212 (Actualizado) -> Cutback Drama Luke has a dream...
# Procesado 594: 10021225 (Actualizado) -> Yvonne Orji: A Whole Me Comedy...
# Procesado 595: 1002125 (Actualizado) -> Sea of Time Animation The floc...
# Procesado 596: 10021261 (Actualizado) -> No Name and Dynamite Action Tw...
# Procesado 597: 1002135 (Actualizado) -> Faded Memories Horror, Comedy ...
# Procesado 598: 10021412 (Actualizado) -> Peridot Drama Peridot is the s...
# Procesado 599: 100215 (Actualizado) -> Another look Drama, History Af...
# Procesado 600: 1002156 (Actualizado) -> Stateside Children It's bath t...
# Procesado 601: 10021624 (Actualizado) -> Phase 6 Drama Between Brighton...
# Procesado 602: 10021626 (Actualizado) -> Things Eternal Drama This anth...
# Procesado 603: 1002166 (Actualizado) -> Free Spirit - Mustangs in Dang...
# Procesado 604: 10021706 (Actualizado) -> Elizabeth Bowes-Lyon: Mother o...
# Procesado 605: 1002177 (Actualizado) -> The Ballad of Johnny Windows D...
# Procesado 606: 1002182 (Actualizado) -> The Sisters Karras Drama; Indi...
# Procesado 607: 10022 (Actualizado) -> The Pacifier Drama A special a...
# Procesado 608: 100221 (Actualizado) -> The day of the cobra Suspense;...
# Procesado 609: 10022196 (Actualizado) -> Human to Human Documentary Hum...
# Procesado 610: 1002226 (Actualizado) -> Midnight Peepshow Suspense An ...
# Procesado 611: 10022299 (Actualizado) -> Back to the present Comedy Whi...
# Procesado 612: 10022313 (Actualizado) -> Housing Complex C Comedy; Horr...
# Procesado 613: 100224 (Actualizado) -> How Much Wood Would A Woodchuc...
# Procesado 614: 1002258 (Actualizado) -> Pray After Reading Suspense; H...
# Procesado 615: 10022637 (Actualizado) -> Say Hey, Willie Mays! Sport Fr...
# Procesado 616: 1002265 (Actualizado) -> They are illusions Drama; Come...
# Procesado 617: 10023 (Actualizado) -> Dragnet Suspense Starring Tom ...
# Procesado 618: 10023035 (Actualizado) -> Photographs Indie; Documentary...
# Procesado 619: 1002305 (Actualizado) -> Secrets of Sport: The Rise and...
# Procesado 620: 1002307 (Actualizado) -> Secrets of sport: Operation un...
# Procesado 621: 1002310 (Actualizado) -> Secrets of sport: The regatta ...
# Procesado 622: 10023144 (Actualizado) -> Live a good life Romance; Urba...
# Procesado 623: 1002315 (Actualizado) -> Please Don't Destroy: The Trea...
# Procesado 624: 1002316 (Actualizado) -> Impressions of Disraeli Drama ...
# Procesado 625: 1002317 (Actualizado) -> BodyShop Drama The ghost of a ...
# Procesado 626: 1002318 (Actualizado) -> Apostles LGBTQ; Drama A schola...
# Procesado 627: 100232 (Actualizado) -> The Princess of the Rail Adven...
# Procesado 628: 1002321 (Actualizado) -> We Need To Break Up Comedy Lit...
# Procesado 629: 10023219 (Actualizado) -> solo effort Indie Every year, ...
# Procesado 630: 1002338 (Actualizado) -> Operation Napoleon Suspense; I...
# Procesado 631: 10023572 (Actualizado) -> The Bride and the Silly Son-in...
# Procesado 632: 100236 (Actualizado) -> House Of Z ‪Documentary‬ HOUSE...
# Procesado 633: 10023624 (Actualizado) -> It's Becquer! Documentary Bécq...
# Procesado 634: 1002373 (Actualizado) -> The Journey Ahead Romance; Dra...
# Procesado 635: 100238 (Actualizado) -> Danger Of Her Drama Watch the ...
# Procesado 636: 100239 (Actualizado) -> The Confused Groom Comedy; Dra...
# Procesado 637: 10023983 (Actualizado) -> City on fire Drama A college s...
# Procesado 638: 10024 (Actualizado) -> My Sister's Keeper Drama Camer...
# Procesado 639: 10024046 (Actualizado) -> My Lovely Bodyguard Romance; D...
# Procesado 640: 100241 (Actualizado) -> I, Frankenstein Action; Fantas...
# Procesado 641: 10024187 (Actualizado) -> Seahorse Man Documentary As se...
# Procesado 642: 10024225 (Actualizado) -> Beyond Metabolism Documentary ...
# Procesado 643: 10024385 (Actualizado) -> The front line of the Ukrainia...
# Procesado 644: 10024407 (Actualizado) -> 3.5 period Fantasy; Romance Sh...
# Procesado 645: 1002442 (Actualizado) -> Yahoo+ Thriller After they fai...
# Procesado 646: 1002443 (Actualizado) -> Tiger's Tail suspense; global ...
# ...
# Procesado 894: 1003874 (Actualizado) -> Chemsexeur, the movie Animatio...
# Procesado 895: 1003876 (Actualizado) -> Mad as Hell Drama When the not...
# Procesado 896: 10038784 (Actualizado) -> About the fact that I was acci...
# Procesado 897: 1003917 (Actualizado) -> The Chicken Thief Animation Si...
# Procesado 898: 1003918 (Actualizado) -> RiffTrax: Supersonic Man Comed...
# Procesado 899: 1003920 (Actualizado) -> RiffTrax: Attack of the Superm...
# Procesado 900: 10039292 (Actualizado) -> Gangs of Lemur Island Document...
# Procesado 901: 10039492 (Actualizado) -> Red suitcase Drama A pickup tr...
# Procesado 902: 100399 (Actualizado) -> Table That Applauds The Most D...
# Procesado 903: 1003990 (Actualizado) -> Children of the Pines Suspense...
# Procesado 904: 1003992 (Actualizado) -> House of Evil Spirits Reality ...
# Procesado 905: 1003994 (Actualizado) -> In the Shadow Reality Our thre...
# Procesado 906: 1003996 (Actualizado) -> Against the Landscape Reality ...
# Procesado 907: 1003998 (Actualizado) -> The Fall Reality Azzkikr Custo...
# Procesado 908: 1003999 (Actualizado) -> Brain Storm Reality The pressu...
# Procesado 909: 10040 (Actualizado) -> Miss Congeniality 2 Drama; Rom...
# Procesado 910: 1004001 (Actualizado) -> Legend of the Magic Arch Reali...
# Procesado 911: 1004002 (Actualizado) -> Amelia's decision Reality It's...
# Procesado 912: 1004003 (Actualizado) -> But We Were Happy Reality Our ...
# Procesado 913: 1004004 (Actualizado) -> ROH: Manhattan Mayhem IV Reali...
# Procesado 914: 10040132 (Actualizado) -> Nazar Andaaz Comedy A carefree...
# Procesado 915: 100402 (Actualizado) -> Marvel Studios' Captain Americ...
# Procesado 916: 1004024 (Actualizado) -> Vickida No Varghodo Comedy, Fa...
# Procesado 917: 10040271 (Actualizado) -> Ria Rabbit Comedy A collection...
# Procesado 918: 10040341 (Actualizado) -> The Woman in the Wall Drama; S...
# Procesado 919: 1004046 (Actualizado) -> Reminiscentia Science Fiction ...
# Procesado 920: 1004048 (Actualizado) -> Caillou: Rosie the Giant Anima...
# Procesado 921: 1004074 (Actualizado) -> Ananya Drama; International An...
# Procesado 922: 10040849 (Actualizado) -> Kelce Sports; Documentaries NF...
# Procesado 923: 10040899 (Actualizado) -> Song Of The Moon Romance Watch...
# Procesado 924: 100409 (Actualizado) -> Over Your Cities Grass Will Gr...
# Procesado 925: 10041124 (Actualizado) -> Katak, the little whale Animat...
# Procesado 926: 10041647 (Actualizado) -> A Love So Beautiful Drama; Rom...
# Procesado 927: 1004171 (Actualizado) -> New Religion Drama Miyabi lost...
# Procesado 928: 10041721 (Actualizado) -> Blindfolded game Drama A simpl...
# Procesado 929: 10041872 (Actualizado) -> The key to the heart Music; Dr...
# Procesado 930: 10041917 (Actualizado) -> House Of Dolls Suspense A fami...
# Procesado 931: 10041920 (Actualizado) -> Looking for the Good Road Come...
# Procesado 932: 10041966 (Actualizado) -> Black Noise Action; Science Fi...
# Procesado 933: 10042 (Actualizado) -> Within Drama, Horror, Thriller...
# Procesado 934: 100420 (Actualizado) -> The awakening of a nation Dram...
# Procesado 935: 100421 (Actualizado) -> Demon King Dante Horror Utsugi...
# Procesado 936: 10042225 (Actualizado) -> Ex 4: Marrying Young Romance; ...
# Procesado 937: 10042248 (Actualizado) -> Holidays in crisis Drama Rajan...
# Procesado 938: 100424 (Actualizado) -> Me Said Children; Animation A ...
# Procesado 939: 1004242 (Actualizado) -> Death Forest Fear Forest 5 Hor...
# Procesado 940: 10042460 (Actualizado) -> The Blockchain Life Suspense; ...
# Procesado 941: 100425 (Actualizado) -> "Celebrity Hunted" suspense; i...
# Procesado 942: 1004252 (Actualizado) -> The Ghost and the Tout Too Com...
# Procesado 943: 100426 (Actualizado) -> Stavisky, the crook of the cen...
# Procesado 944: 1004266 (Actualizado) -> Full Contact - A Way of Life I...
# Procesado 945: 1004269 (Actualizado) -> The Jessica Cabin ‪Comedy‬; ‪H...
# Procesado 946: 1004284 (Actualizado) -> Our Home 2: The Messengers Dra...
# Procesado 947: 1004290 (Actualizado) -> I am a servant. Comedy, Fantas...
# Procesado 948: 10042981 (Actualizado) -> You & I Drama; Romance An unex...
# Procesado 949: 10042987 (Actualizado) -> Breaking the News Documentary ...
# Procesado 950: 10042994 (Actualizado) -> Estonia Drama A true-life dram...
# Procesado 951: 100430 (Actualizado) -> Po Cheong-cheon's Seven Heroes...
# Procesado 952: 10043042 (Actualizado) -> My Muslim Husband Documentary ...
# Procesado 953: 10043148 (Actualizado) -> Ron Kamonohashi's Forbidden De...
# Procesado 954: 10043158 (Actualizado) -> Comedy Royale Reality Twenty o...
# Procesado 955: 1004321 (Actualizado) -> Picturing the Presidents Docum...
# Procesado 956: 10043371 (Actualizado) -> Lélo, freedom and painting Doc...
# Procesado 957: 10043405 (Actualizado) -> Kanda Naal Mudhal - Uravugalin...
# Procesado 958: 10043434 (Actualizado) -> First meeting Drama Tina, a fa...
# Procesado 959: 100436 (Actualizado) -> Jamie Foxx: I Might Need Secur...
# Procesado 960: 1004364 (Actualizado) -> Hider In My House Drama; Suspe...
# Procesado 961: 10043681 (Actualizado) -> A Christmas of Love Comedy; Ro...
# Procesado 962: 1004375 (Actualizado) -> Complicated Affairs Comedy Low...
# Procesado 963: 1004376 (Actualizado) -> Author of "Unknown Soldier", V...
# Procesado 964: 1004387 (Actualizado) -> Caribou at Glastonbury 2022 Cr...
# Procesado 965: 100439 (Actualizado) -> Shake Rattle & Roll 13 Drama; ...
# Procesado 966: 10043923 (Actualizado) -> I will go Drama In autumn 1985...
# Procesado 967: 1004397 (Actualizado) -> A Night With Janis Joplin Musi...
# Procesado 968: 10044 (Actualizado) -> Tokyo Powerman Action, Comedy ...
# Procesado 969: 100441 (Actualizado) -> Legacy: Live In Baden-Baden Mu...
# Procesado 970: 10044104 (Actualizado) -> Luto a Lot Documentary The fat...
# Procesado 971: 10044105 (Actualizado) -> standstill Documentary Empty r...
# Procesado 972: 10044212 (Actualizado) -> Babygirl Drama; Romance; Suspe...
# Procesado 973: 10044222 (Actualizado) -> Flowers bloom even in the sand...
# Procesado 974: 100443 (Actualizado) -> In the land of the Cajuns: the...
# Procesado 975: 10044356 (Actualizado) -> The Killers Club Drama When a ...
# Procesado 976: 10044473 (Actualizado) -> Angel Baby Drama; Suspense A w...
# Procesado 977: 1004461 (Actualizado) -> Bantamweight Drama Enrique, a ...
# Procesado 978: 10044620 (Actualizado) -> My Uncanny Destiny Romance; Dr...
# Procesado 979: 10044621 (Actualizado) -> Namnam Drama; Romance A drama ...
# Procesado 980: 10044623 (Actualizado) -> Robbery Cassette Adventure; Co...
# Procesado 981: 10044624 (Actualizado) -> Against the Ropes Sport; Drama...
# Procesado 982: 10044677 (Actualizado) -> Unforgotten Night Romance Watc...
# Procesado 983: 1004469 (Actualizado) -> My Dad's on Death Row Document...
# Procesado 984: 10044779 (Actualizado) -> Amal: A free spirit Drama Amal...
# Procesado 985: 10044782 (Actualizado) -> A Bug's Life: The Real Adventu...
# Procesado 986: 100449 (Actualizado) -> The endless flame of Gehenna D...
# Procesado 987: 10044998 (Actualizado) -> As We Speak: El Rap a Jucio Mu...
# Procesado 988: 10045 (Actualizado) -> District 13 Crime; Action In a...
# Procesado 989: 10045043 (Actualizado) -> BULLBUSTER ‪Animation‬; ‪Anime...
# Procesado 990: 10045056 (Actualizado) -> Dog Love Signals Lighthearted ...
# Procesado 991: 10045092 (Actualizado) -> Every Little Thing Documentary...
# Procesado 992: 10045115 (Actualizado) -> Breath of Life International; ...
# Procesado 993: 1004517 (Actualizado) -> Up Line Children After seeing ...
# Procesado 994: 1004518 (Actualizado) -> Snarky Puppy at Glastonbury 20...
# Procesado 995: 1004523 (Actualizado) -> Nonstop Fantasy When ghosts fr...
# Procesado 996: 1004526 (Actualizado) -> Metallica: Live at NOS Alive F...
# Procesado 997: 1004529 (Actualizado) -> An Afternoon Knows Children Oh...
# Procesado 998: 10045340 (Actualizado) -> Scar Suspense After surviving ...
# Procesado 999: 100454 (Actualizado) -> Bullfight comedy The backgroun...
# Procesado 1000: 1004555 (Actualizado) -> Sidonia in Japan Drama While o...
# Progreso: 1000 documentos procesados.
# Procesado 1001: 100456 (Actualizado) -> Bendtner & Philine Reality We ...
# Procesado 1002: 1004563 (Actualizado) -> R.I.P. Van Winkle Suspense A y...
# Procesado 1003: 10045644 (Actualizado) -> Nobody in the forest Thriller ...
# Procesado 1004: 10045665 (Actualizado) -> Pau's world Animation For Pau,...
# Procesado 1005: 10045669 (Actualizado) -> Brando El Shark Drama To get f...
# Procesado 1006: 10045685 (Actualizado) -> Face Me Drama A genius plastic...
# Procesado 1007: 10045694 (Actualizado) -> Sweet Tweets Children Sweet Tw...
# Procesado 1008: 10045696 (Actualizado) -> Seetha Raman Drama Seetha gets...
# Procesado 1009: 10045700 (Actualizado) -> Ryunosuke Kamiki's Shooting Br...
# Procesado 1010: 1004574 (Actualizado) -> Return of the Miyata Busters D...
# Procesado 1011: 10045749 (Actualizado) -> Kenshin Drama The legendary "H...
# Procesado 1012: 1004578 (Actualizado) -> Winged Tiger Movies (Japanese ...
# Procesado 1013: 100458 (Actualizado) -> Explosion! Runaway Game Action...
# Procesado 1014: 1004580 (Actualizado) -> Welcome to the Supernatural Fo...
# Procesado 1015: 1004584 (Actualizado) -> Ride to Nowhere Drama Ade is i...
# Procesado 1016: 1004592 (Actualizado) -> Out of my skin Drama, Romance ...
# Procesado 1017: 1004598 (Actualizado) -> Anhell69 Documentary A hearse ...
# Procesado 1018: 10046 (Actualizado) -> The Adventures of Blueberry Ad...
# Procesado 1019: 100460 (Actualizado) -> Direct Hit Hell Fist Great Rev...
# Procesado 1020: 100461 (Actualizado) -> Amakusa Shiro Tokisada Japanes...
# Procesado 1021: 1004610 (Actualizado) -> Abnormality Hunter: Uniform Ta...
# Procesado 1022: 1004612 (Actualizado) -> Albertine Where Are You? Drama...
# Procesado 1023: 10046120 (Actualizado) -> Sit Down with Stand Up Udom Ta...
# Procesado 1024: 1004615 (Actualizado) -> Nostos Science Fiction, Drama,...
# Procesado 1025: 1004616 (Actualizado) -> sapling Children; Educational ...
# Procesado 1026: 1004617 (Actualizado) -> Little Queen Drama Ciociaria, ...
# Procesado 1027: 100463 (Actualizado) -> Ghost Cat Mansion Horror On th...
# Procesado 1028: 1004635 (Actualizado) -> Because You're Dead to Me Susp...
# Procesado 1029: 10046433 (Actualizado) -> Vyooham suspense; global A new...
# Procesado 1030: 1004645 (Actualizado) -> The Bride in the Box Indie On ...
# Procesado 1031: 10046546 (Actualizado) -> Our Dating Sim Drama; Romance ...
# Procesado 1032: 1004660 (Actualizado) -> An Arm's Length World Document...
# Procesado 1033: 10046629 (Actualizado) -> Stuck Outside of Life Drama An...
# Procesado 1034: 10046662 (Actualizado) -> Faster! Humanity's Quest to Sa...
# Procesado 1035: 10046666 (Actualizado) -> Warm On A Cold Night Romance; ...
# Procesado 1036: 1004670 (Actualizado) -> Freedom on Fire: Ukraine's Fig...
# Procesado 1037: 1004674 (Actualizado) -> Hitman: The Ricky Hatton Story...
# Procesado 1038: 1004677 (Actualizado) -> A Compassionate Spy History Th...
# Procesado 1039: 1004678 (Actualizado) -> Music for Black Pigeons Docume...
# Procesado 1040: 100468 (Actualizado) -> They Have Changed Their Face M...
# Procesado 1041: 1004684 (Actualizado) -> Pale Blue Peter Children When ...
# Procesado 1042: 1004685 (Actualizado) -> Nuclear Now Documentary In the...
# Procesado 1043: 1004691 (Actualizado) -> Christmas Craft Fair Massacre ...
# Procesado 1044: 10047 (Actualizado) -> The Messenger: The Story Of Jo...
# Procesado 1045: 100470 (Actualizado) -> The Three Musketeers of the We...
# Procesado 1046: 10047564 (Actualizado) -> History of the Rose Drama Huan...
# Procesado 1047: 10047575 (Actualizado) -> Apartment 404 Comedy; Internat...
# Procesado 1048: 10047589 (Actualizado) -> The Money Game Improvisational...
# Procesado 1049: 1004766 (Actualizado) -> That September Comedy In "Sept...
# Procesado 1050: 1004767 (Actualizado) -> He doesn't do that anyway! Dra...
# ---------------------------------------------------------------------------
# _MultiThreadedRendezvous                  Traceback (most recent call last)
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\grpc_helpers.py:116, in _StreamingResponseIterator.__next__(self)
#     115         return result
# --> 116     return next(self._wrapped)
#     117 except grpc.RpcError as exc:
#     118     # If the stream has already returned data, we cannot recover here.
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\grpc\_channel.py:543, in _Rendezvous.__next__(self)
#     542 def __next__(self):
# --> 543     return self._next()
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\grpc\_channel.py:952, in _MultiThreadedRendezvous._next(self)
#     951 else:
# --> 952     raise self
#     954 def _response_ready():
#
# _MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.DEADLINE_EXCEEDED
# 	details = "Deadline Exceeded"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Deadline Exceeded", grpc_status:4, created_time:"2025-03-10T19:22:09.978066+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# DeadlineExceeded                          Traceback (most recent call last)
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\firestore_v1\query.py:411, in Query._make_stream(self, transaction, retry, timeout, explain_options)
#     410 try:
# --> 411     response = next(response_iterator, None)
#     412 except exceptions.GoogleAPICallError as exc:
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\grpc_helpers.py:119, in _StreamingResponseIterator.__next__(self)
#     117 except grpc.RpcError as exc:
#     118     # If the stream has already returned data, we cannot recover here.
# --> 119     raise exceptions.from_grpc_error(exc) from exc
#
# DeadlineExceeded: 504 Deadline Exceeded
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 131
#     127         print(f"Se encontraron {len(failed_embeddings)} embeddings fallidos. IDs guardados en failed_embeddings.json")
#     129     print(f"Finalizado. Total de documentos procesados: {total_docs}. Documentos Nuevos o actualizados: {updated_docs}")
# --> 131 process_and_store_embeddings()
#
# Cell In[7], line 41, in process_and_store_embeddings()
#      38 text_batch = []
#      39 doc_batch = []
# ---> 41 for doc in docs:
#      42     try:
#      43         data = doc.to_dict()
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\firestore_v1\stream_generator.py:58, in StreamGenerator.__next__(self)
#      56 def __next__(self) -> T:
#      57     try:
# ---> 58         return self._generator.__next__()
#      59     except StopIteration as e:
#      60         # If explain_metrics is available, it would be returned.
#      61         if e.value:
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\firestore_v1\query.py:413, in Query._make_stream(self, transaction, retry, timeout, explain_options)
#     411     response = next(response_iterator, None)
#     412 except exceptions.GoogleAPICallError as exc:
# --> 413     if self._retry_query_after_exception(exc, retry, transaction):
#     414         new_query = self.start_after(last_snapshot)
#     415         response_iterator, _ = new_query._get_stream_iterator(
#     416             transaction,
#     417             retry,
#     418             timeout,
#     419         )
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\firestore_v1\query.py:264, in Query._retry_query_after_exception(self, exc, retry, transaction)
#     262         transport = self._client._firestore_api._transport
#     263         gapic_callable = transport.run_query
# --> 264         retry = gapic_callable._retry
#     265     return retry._predicate(exc)
#     267 return False
#
# AttributeError: '_UnaryStreamMultiCallable' object has no attribute '_retry'

# %%
import vertexai
from vertexai.language_models import TextEmbeddingModel
from google.cloud import bigquery, storage, aiplatform
import pandas as pd
import json
import os
from uuid import uuid4

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"  
LOCATION = "europe-southwest1" 
BUCKET_NAME = "embeddings_new_bucket"  
GCS_PREFIX = "embeddings/movies_and_series"  
BQ_QUERY = "SELECT tmdb_id AS ID, title, genres, synopsis FROM `bubbo-dfba0.content.best_content_translated_py`"
EMBEDDING_MODEL = "text-multilingual-embedding-002" 


BATCH_SIZE = 1000 

vertexai.init(project=PROJECT, location=LOCATION)
embedding_model = TextEmbeddingModel.from_pretrained(EMBEDDING_MODEL)
bq_client = bigquery.Client(project=PROJECT)
storage_client = storage.Client(project=PROJECT)

# 1. Obtener datos de BigQuery (por páginas)
def get_data_from_bigquery():
    print("Ejecutando la consulta en BigQuery...")
    
    job = bq_client.query(BQ_QUERY)
    iterator = job.result(page_size=BATCH_SIZE)  
    pages = iterator.pages
    
    print("Consulta ejecutada, procesando los resultados...")

    all_rows = []

    for page_num, page in enumerate(pages, start=1):
        print(f"Procesando página {page_num}...")
        all_rows.extend(page)

    print("Todas las páginas procesadas, verificando la estructura de los datos...")

    # Extraer las tuplas de los objetos Row
    all_rows = [list(row) for row in all_rows]  # Convertimos cada Row a una lista simple

    print(f"Estructura de all_rows: {all_rows[:5]}")  # Muestra las primeras 5 filas para verificar

    # Convertir todas las filas a un DataFrame de pandas
    columns = ['ID', 'title', 'genres', 'synopsis']  # Definir las columnas esperadas
    df = pd.DataFrame(all_rows, columns=columns)
    print("Columnas en el DataFrame:", df.columns)

    # Mostrar las primeras filas para ver el contenido
    print("Primeros registros del DataFrame:")
    print(df.head())  # Mostrar las primeras filas del DataFrame

    # Obtener los datos de las columnas que nos interesan
    ids = df["ID"].astype(str).tolist()  # Obtener los IDs
    df["combined"] = df.apply(lambda row: f"{row['title']}. Géneros: {row['genres']}. Sinopsis: {row['synopsis']}", axis=1)
    texts = df["combined"].astype(str).tolist()
    
    print(f"Se han obtenido {len(ids)} registros de BigQuery.")
    
    return ids, texts


def create_embeddings(texts, batch_size=250):
    all_embeddings = []

    for i in range(0, len(texts), batch_size):
        batch = texts[i:i + batch_size]
        print(f"Procesando batch {i // batch_size + 1} con {len(batch)} textos...")
        
        embeddings = embedding_model.get_embeddings(batch)
        all_embeddings.extend([e.values for e in embeddings])

    return all_embeddings


# 3. Subir los embeddings a GCS (Google Cloud Storage)
def upload_to_gcs(local_file_path, gcs_path):
    bucket = storage_client.bucket(BUCKET_NAME)  
    blob = bucket.blob(gcs_path)  
    blob.upload_from_filename(local_file_path)  
    print(f"Subido a GCS: {gcs_path}")
    
def gcs_file_exists(gcs_path):
    bucket = storage_client.bucket(BUCKET_NAME)
    blob = bucket.blob(gcs_path)
    return blob.exists()


# Función para guardar los embeddings en un archivo JSONL y subir a GCS
def save_embeddings_to_gcs(ids, embeddings, part):
    jsonl_path = f"/tmp/embeddings_part_{part}.jsonl"  
    with open(jsonl_path, "w") as f:
        for i in range(len(ids)):
            item = {"id": ids[i], "embedding": embeddings[i]}  
            f.write(json.dumps(item) + "\n")  
    
    gcs_path = f"{GCS_PREFIX}/embeddings_part_{part}.jsonl"  
    upload_to_gcs(jsonl_path, gcs_path)  
    return f"gs://{BUCKET_NAME}/{gcs_path}"

# 4. Procesar en batches, crear embeddings y subir a GCS
def process_and_upload_batches():
    print("Iniciando el proceso de obtener datos y crear embeddings...")

    ids, texts = get_data_from_bigquery()
    if not ids or not texts:
        print("Error al obtener los datos. Terminando el proceso.")
        return ""

    part_counter = 1
    for i in range(0, len(texts), BATCH_SIZE):
        batch_ids = ids[i:i + BATCH_SIZE]
        batch_texts = texts[i:i + BATCH_SIZE]

        gcs_filename = f"{GCS_PREFIX}/embeddings_part_{part_counter}.jsonl"

        if gcs_file_exists(gcs_filename):
            print(f"Lote {part_counter} ya existe en GCS, saltando...")
            part_counter += 1
            continue

        print(f"\nProcesando lote {part_counter} con {len(batch_texts)} textos...")

        embeddings = create_embeddings(batch_texts)

        print(f"Subiendo lote {part_counter} a GCS...")
        gcs_file_uri = save_embeddings_to_gcs(batch_ids, embeddings, part=part_counter)

        part_counter += 1

    print("Todos los embeddings procesados y subidos.")
    return f"gs://{BUCKET_NAME}/{GCS_PREFIX}/"


# MAIN
if __name__ == "__main__":
    print("Comenzando el proceso de batch...")
    gcs_file_uri = process_and_upload_batches()  
    print(f"Embeddings subidos a: {gcs_file_uri}")
# Out:
# Comenzando el proceso de batch...
# Iniciando el proceso de obtener datos y crear embeddings...
# Ejecutando la consulta en BigQuery...
# Consulta ejecutada, procesando los resultados...
# Procesando página 1...
# Procesando página 2...
# Procesando página 3...
# Procesando página 4...
# Procesando página 5...
# Procesando página 6...
# Procesando página 7...
# Procesando página 8...
# Procesando página 9...
# Procesando página 10...
# Procesando página 11...
# Procesando página 12...
# Procesando página 13...
# Procesando página 14...
# Procesando página 15...
# Procesando página 16...
# Procesando página 17...
# Procesando página 18...
# Procesando página 19...
# Procesando página 20...
# Procesando página 21...
# Procesando página 22...
# Procesando página 23...
# Procesando página 24...
# Procesando página 25...
# Procesando página 26...
# Procesando página 27...
# Procesando página 28...
# Procesando página 29...
# Procesando página 30...
# Procesando página 31...
# Procesando página 32...
# Procesando página 33...
# Procesando página 34...
# Procesando página 35...
# Procesando página 36...
# Procesando página 37...
# Procesando página 38...
# Procesando página 39...
# Procesando página 40...
# Procesando página 41...
# Procesando página 42...
# Procesando página 43...
# Procesando página 44...
# Procesando página 45...
# Procesando página 46...
# Procesando página 47...
# Procesando página 48...
# Procesando página 49...
# Procesando página 50...
# Procesando página 51...
# Procesando página 52...
# Procesando página 53...
# Procesando página 54...
# Procesando página 55...
# Procesando página 56...
# Procesando página 57...
# Procesando página 58...
# Procesando página 59...
# Procesando página 60...
# Procesando página 61...
# Procesando página 62...
# Procesando página 63...
# Procesando página 64...
# Procesando página 65...
# Procesando página 66...
# Procesando página 67...
# Procesando página 68...
# Procesando página 69...
# Procesando página 70...
# Procesando página 71...
# Procesando página 72...
# Procesando página 73...
# Procesando página 74...
# Procesando página 75...
# Procesando página 76...
# Procesando página 77...
# Procesando página 78...
# Procesando página 79...
# Procesando página 80...
# Procesando página 81...
# Procesando página 82...
# Procesando página 83...
# Procesando página 84...
# Procesando página 85...
# Procesando página 86...
# Procesando página 87...
# Procesando página 88...
# Procesando página 89...
# Procesando página 90...
# Procesando página 91...
# Procesando página 92...
# Procesando página 93...
# Procesando página 94...
# Procesando página 95...
# Procesando página 96...
# Procesando página 97...
# Procesando página 98...
# Procesando página 99...
# Procesando página 100...
# Procesando página 101...
# Procesando página 102...
# Procesando página 103...
# Procesando página 104...
# Procesando página 105...
# Procesando página 106...
# Procesando página 107...
# Procesando página 108...
# Procesando página 109...
# Procesando página 110...
# Procesando página 111...
# Procesando página 112...
# Procesando página 113...
# Procesando página 114...
# Procesando página 115...
# Procesando página 116...
# Procesando página 117...
# Procesando página 118...
# Procesando página 119...
# Procesando página 120...
# Procesando página 121...
# Procesando página 122...
# Procesando página 123...
# Procesando página 124...
# Procesando página 125...
# Procesando página 126...
# Procesando página 127...
# Procesando página 128...
# Procesando página 129...
# Procesando página 130...
# Procesando página 131...
# Procesando página 132...
# Procesando página 133...
# Procesando página 134...
# Procesando página 135...
# Procesando página 136...
# Procesando página 137...
# Procesando página 138...
# Procesando página 139...
# Procesando página 140...
# Procesando página 141...
# Procesando página 142...
# Procesando página 143...
# Procesando página 144...
# Procesando página 145...
# Procesando página 146...
# Procesando página 147...
# Procesando página 148...
# Procesando página 149...
# Procesando página 150...
# Procesando página 151...
# Procesando página 152...
# Procesando página 153...
# Procesando página 154...
# Procesando página 155...
# Procesando página 156...
# Procesando página 157...
# Procesando página 158...
# Procesando página 159...
# Procesando página 160...
# Procesando página 161...
# Procesando página 162...
# Procesando página 163...
# Procesando página 164...
# Procesando página 165...
# Procesando página 166...
# Procesando página 167...
# Procesando página 168...
# Procesando página 169...
# Procesando página 170...
# Procesando página 171...
# Procesando página 172...
# Procesando página 173...
# Procesando página 174...
# Procesando página 175...
# Procesando página 176...
# Procesando página 177...
# Procesando página 178...
# Procesando página 179...
# Procesando página 180...
# Procesando página 181...
# Procesando página 182...
# Procesando página 183...
# Procesando página 184...
# Procesando página 185...
# Procesando página 186...
# Procesando página 187...
# Procesando página 188...
# Procesando página 189...
# Procesando página 190...
# Procesando página 191...
# Procesando página 192...
# Procesando página 193...
# Procesando página 194...
# Procesando página 195...
# Procesando página 196...
# Procesando página 197...
# Procesando página 198...
# Procesando página 199...
# Procesando página 200...
# Procesando página 201...
# Procesando página 202...
# Procesando página 203...
# Procesando página 204...
# Procesando página 205...
# Procesando página 206...
# Procesando página 207...
# Procesando página 208...
# Procesando página 209...
# Procesando página 210...
# Procesando página 211...
# Procesando página 212...
# Procesando página 213...
# Procesando página 214...
# Procesando página 215...
# Procesando página 216...
# Procesando página 217...
# Procesando página 218...
# Procesando página 219...
# Procesando página 220...
# Procesando página 221...
# Procesando página 222...
# Procesando página 223...
# Procesando página 224...
# Procesando página 225...
# Procesando página 226...
# Procesando página 227...
# Procesando página 228...
# Procesando página 229...
# Procesando página 230...
# Procesando página 231...
# Procesando página 232...
# Procesando página 233...
# Procesando página 234...
# Procesando página 235...
# Procesando página 236...
# Procesando página 237...
# Procesando página 238...
# Procesando página 239...
# Procesando página 240...
# Procesando página 241...
# Procesando página 242...
# Procesando página 243...
# Procesando página 244...
# Procesando página 245...
# Procesando página 246...
# Procesando página 247...
# Procesando página 248...
# Procesando página 249...
# Procesando página 250...
# Procesando página 251...
# Procesando página 252...
# Procesando página 253...
# Procesando página 254...
# Procesando página 255...
# Procesando página 256...
# Procesando página 257...
# Procesando página 258...
# Procesando página 259...
# Procesando página 260...
# Procesando página 261...
# Procesando página 262...
# Procesando página 263...
# Procesando página 264...
# Procesando página 265...
# Procesando página 266...
# Procesando página 267...
# Procesando página 268...
# Procesando página 269...
# Procesando página 270...
# Procesando página 271...
# Procesando página 272...
# Procesando página 273...
# Procesando página 274...
# Procesando página 275...
# Procesando página 276...
# Procesando página 277...
# Procesando página 278...
# Procesando página 279...
# Procesando página 280...
# Procesando página 281...
# Procesando página 282...
# Procesando página 283...
# Procesando página 284...
# Procesando página 285...
# Procesando página 286...
# Procesando página 287...
# Procesando página 288...
# Procesando página 289...
# Procesando página 290...
# Procesando página 291...
# Procesando página 292...
# Procesando página 293...
# Procesando página 294...
# Procesando página 295...
# Procesando página 296...
# Procesando página 297...
# Procesando página 298...
# Procesando página 299...
# Procesando página 300...
# Procesando página 301...
# Procesando página 302...
# Procesando página 303...
# Procesando página 304...
# Procesando página 305...
# Procesando página 306...
# Procesando página 307...
# Procesando página 308...
# Procesando página 309...
# Procesando página 310...
# Procesando página 311...
# Procesando página 312...
# Procesando página 313...
# Procesando página 314...
# Procesando página 315...
# Procesando página 316...
# Procesando página 317...
# Procesando página 318...
# Procesando página 319...
# Procesando página 320...
# Procesando página 321...
# Procesando página 322...
# Procesando página 323...
# Procesando página 324...
# Procesando página 325...
# Procesando página 326...
# Procesando página 327...
# Procesando página 328...
# Procesando página 329...
# Procesando página 330...
# Procesando página 331...
# Procesando página 332...
# Procesando página 333...
# Procesando página 334...
# Procesando página 335...
# Procesando página 336...
# Procesando página 337...
# Procesando página 338...
# Procesando página 339...
# Procesando página 340...
# Procesando página 341...
# Procesando página 342...
# Procesando página 343...
# Procesando página 344...
# Procesando página 345...
# Procesando página 346...
# Procesando página 347...
# Procesando página 348...
# Procesando página 349...
# Procesando página 350...
# Procesando página 351...
# Procesando página 352...
# Procesando página 353...
# Procesando página 354...
# Procesando página 355...
# Procesando página 356...
# Procesando página 357...
# Procesando página 358...
# Procesando página 359...
# Procesando página 360...
# Procesando página 361...
# Procesando página 362...
# Procesando página 363...
# Procesando página 364...
# Procesando página 365...
# Procesando página 366...
# Procesando página 367...
# Procesando página 368...
# Procesando página 369...
# Procesando página 370...
# Procesando página 371...
# Procesando página 372...
# Procesando página 373...
# Procesando página 374...
# Procesando página 375...
# Procesando página 376...
# Procesando página 377...
# Procesando página 378...
# Procesando página 379...
# Procesando página 380...
# Procesando página 381...
# Procesando página 382...
# Procesando página 383...
# Procesando página 384...
# Procesando página 385...
# Procesando página 386...
# Procesando página 387...
# Procesando página 388...
# Procesando página 389...
# Procesando página 390...
# Procesando página 391...
# Procesando página 392...
# Procesando página 393...
# Procesando página 394...
# Procesando página 395...
# Procesando página 396...
# Procesando página 397...
# Procesando página 398...
# Procesando página 399...
# Procesando página 400...
# Procesando página 401...
# Procesando página 402...
# Procesando página 403...
# Procesando página 404...
# Procesando página 405...
# Procesando página 406...
# Procesando página 407...
# Procesando página 408...
# Procesando página 409...
# Procesando página 410...
# Procesando página 411...
# Procesando página 412...
# Procesando página 413...
# Procesando página 414...
# Procesando página 415...
# Procesando página 416...
# Procesando página 417...
# Procesando página 418...
# Procesando página 419...
# Procesando página 420...
# Procesando página 421...
# Procesando página 422...
# Procesando página 423...
# Procesando página 424...
# Procesando página 425...
# Procesando página 426...
# Procesando página 427...
# Procesando página 428...
# Procesando página 429...
# Procesando página 430...
# Procesando página 431...
# Procesando página 432...
# Procesando página 433...
# Procesando página 434...
# Procesando página 435...
# Procesando página 436...
# Procesando página 437...
# Procesando página 438...
# Procesando página 439...
# Procesando página 440...
# Procesando página 441...
# Procesando página 442...
# Procesando página 443...
# Procesando página 444...
# Procesando página 445...
# Procesando página 446...
# Procesando página 447...
# Procesando página 448...
# Procesando página 449...
# Procesando página 450...
# Procesando página 451...
# Procesando página 452...
# Procesando página 453...
# Procesando página 454...
# Procesando página 455...
# Procesando página 456...
# Procesando página 457...
# Procesando página 458...
# Procesando página 459...
# Procesando página 460...
# Procesando página 461...
# Procesando página 462...
# Procesando página 463...
# Procesando página 464...
# Procesando página 465...
# Procesando página 466...
# Procesando página 467...
# Procesando página 468...
# Procesando página 469...
# Procesando página 470...
# Procesando página 471...
# Procesando página 472...
# Procesando página 473...
# Procesando página 474...
# Procesando página 475...
# Procesando página 476...
# Procesando página 477...
# Procesando página 478...
# Procesando página 479...
# Procesando página 480...
# Procesando página 481...
# Procesando página 482...
# Procesando página 483...
# Procesando página 484...
# Procesando página 485...
# Procesando página 486...
# Procesando página 487...
# Procesando página 488...
# Procesando página 489...
# Procesando página 490...
# Procesando página 491...
# Procesando página 492...
# Procesando página 493...
# Procesando página 494...
# Procesando página 495...
# Procesando página 496...
# Procesando página 497...
# Procesando página 498...
# Procesando página 499...
# Procesando página 500...
# Procesando página 501...
# Procesando página 502...
# Procesando página 503...
# Todas las páginas procesadas, verificando la estructura de los datos...
# Estructura de all_rows: [['528393', 'Ballet Now', '\n        Art\n      ', 'Dance sensation Tiler Peck, one of the principal dancers of the New York City Ballet company, curates a three-day dance series entitled ‘Ballet Now’ which seeks to push boundaries and integrate unexpected elements into performances which will not only delight ballet’s devout followers but also create new fans. Produced by Emmy-winning Elisabeth Moss and directed by Steven Cantor (Dancer) this feature-length film captures the creative process behind the scenes at the famed Dorothy Chandler Pavilion – bringing dancers, choreographers and styles from all over the world together for three magical nights of performances.'], ['473176', 'Lots of Kids, a Monkey and a Castle', '\n        Comedy\n      ', '“There’s something a little bit magic about Julita, something of the fairytale” (Variety). Matriarch Julita’s three childhood wishes have been granted: lots of kids, a monkey, and a castle. But after the financial crisis hits Spain the family loses their castle but not their sense of humour and family unity; and through the wealth of hoarded objects she has accumulated over 81 years, a rich family portrait is revealed.'], ['2513339', 'Must-see! The whole thing ☆ Mai Mizusawa', '-, Entertainment - Gravure', 'Underboob Venus☆H-cup Mizusawa Mai appears! Stretch with Mai-chan, a cheerleader from Osaka! Her skirt flutters and cheers give her strength. The moment she takes it off, the words "It\'s huge!" are heard. The yellow bikini stands out against her beautiful, lean body. / Spend a relaxing day at the resort with Mai-chan! Mai-chan, wearing a see-through resort gown, invites you to the rooftop. Sunbathe together in a cute floral swimsuit. / Married woman Mai-chan\'s morning shower, and of course her husband is you. When she takes off her clean, tight outfit, she reveals a stimulating swimsuit...! The shower moistens Mai-chan. / Detective Mai has a 100% confession rate! First, she shows off her butt in fishnet stockings and is questioned! Under her uniform, she is wearing a sexy, red, modified swimsuit.... She has no choice but to confess, "I like the detective!" In the end, the detective catches her and questions her back!'], ['2695276', 'Must-see! All of Rei Toda', '-, Entertainment - Gravure', "Enjoy her beautiful buttocks, polished to the max! Toda Rei appears on DGC! Rei is a new secretary who has been dispatched to the office. The president praises her buttocks performance, calling it the best design! Next, she performs a sexy dance in a black-walled Western-style building, grinding her hips! In the afternoon, young wife Rei appears with a stimulating red knit. But when she takes it off, it's amazing. At the end, she shows off a black bikini over a sheer shawl. Her proud buttocks bounce around in the bathtub!"], ['2695268', 'Must-see! The whole thing ☆ Asuka Kishi', '-, Entertainment - Gravure', 'A gorgeous girl with a 90cm bust and G-cup! Kishi Asuka-chan appears in the "Must-Show! All-Out" series! First, she stretches in a bright red belly-baring look! Exercise with the lively Asuka-chan. Next, a slightly naughty policewoman, who will surprise you with her voluptuous body when she takes off her clothes. Then, she moves to the bedroom and rolls around on the bed, so defenseless that her clothes get exposed! She wakes up in a lace shawl and white swimsuit. Her flapping wings make her look like an angel! Finally, she plays with the fluorescent lights in a golden swimsuit. The mysterious light that shines on her bottom is gorgeous☆☆']]
# Columnas en el DataFrame: Index(['ID', 'title', 'genres', 'synopsis'], dtype='object')
# Primeros registros del DataFrame:
#         ID                                     title  \
# 0   528393                                Ballet Now
# 1   473176       Lots of Kids, a Monkey and a Castle
# 2  2513339  Must-see! The whole thing ☆ Mai Mizusawa
# 3  2695276                 Must-see! All of Rei Toda
# 4  2695268   Must-see! The whole thing ☆ Asuka Kishi
#
#                        genres  \
# 0       \n        Art\n
# 1    \n        Comedy\n
# 2  -, Entertainment - Gravure
# 3  -, Entertainment - Gravure
# 4  -, Entertainment - Gravure
#
#                                             synopsis
# 0  Dance sensation Tiler Peck, one of the princip...
# 1  “There’s something a little bit magic about Ju...
# 2  Underboob Venus☆H-cup Mizusawa Mai appears! St...
# 3  Enjoy her beautiful buttocks, polished to the ...
# 4  A gorgeous girl with a 90cm bust and G-cup! Ki...
# Se han obtenido 502850 registros de BigQuery.
# Lote 1 ya existe en GCS, saltando...
# Lote 2 ya existe en GCS, saltando...
# Lote 3 ya existe en GCS, saltando...
# Lote 4 ya existe en GCS, saltando...
# Lote 5 ya existe en GCS, saltando...
# Lote 6 ya existe en GCS, saltando...
# Lote 7 ya existe en GCS, saltando...
# Lote 8 ya existe en GCS, saltando...
# Lote 9 ya existe en GCS, saltando...
# Lote 10 ya existe en GCS, saltando...
#
# Procesando lote 11 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 11 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_11.jsonl
#
# Procesando lote 12 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 12 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_12.jsonl
#
# Procesando lote 13 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 13 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_13.jsonl
#
# Procesando lote 14 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 14 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_14.jsonl
#
# Procesando lote 15 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 15 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_15.jsonl
#
# Procesando lote 16 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 16 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_16.jsonl
#
# Procesando lote 17 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 17 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_17.jsonl
#
# Procesando lote 18 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 18 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_18.jsonl
#
# Procesando lote 19 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 19 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_19.jsonl
#
# Procesando lote 20 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 20 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_20.jsonl
#
# Procesando lote 21 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 21 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_21.jsonl
#
# Procesando lote 22 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 22 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_22.jsonl
#
# Procesando lote 23 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 23 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_23.jsonl
#
# Procesando lote 24 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 24 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_24.jsonl
#
# Procesando lote 25 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 25 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_25.jsonl
#
# Procesando lote 26 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 26 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_26.jsonl
#
# Procesando lote 27 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 27 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_27.jsonl
#
# Procesando lote 28 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 28 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_28.jsonl
#
# Procesando lote 29 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 29 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_29.jsonl
#
# Procesando lote 30 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 30 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_30.jsonl
#
# Procesando lote 31 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 31 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_31.jsonl
#
# Procesando lote 32 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 32 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_32.jsonl
#
# Procesando lote 33 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 33 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_33.jsonl
#
# Procesando lote 34 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 34 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_34.jsonl
#
# Procesando lote 35 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 35 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_35.jsonl
#
# Procesando lote 36 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 36 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_36.jsonl
#
# Procesando lote 37 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 37 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_37.jsonl
#
# Procesando lote 38 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 38 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_38.jsonl
#
# Procesando lote 39 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 39 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_39.jsonl
#
# Procesando lote 40 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 40 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_40.jsonl
#
# Procesando lote 41 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 41 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_41.jsonl
#
# Procesando lote 42 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 42 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_42.jsonl
#
# Procesando lote 43 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 43 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_43.jsonl
#
# Procesando lote 44 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 44 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_44.jsonl
#
# Procesando lote 45 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 45 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_45.jsonl
#
# Procesando lote 46 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 46 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_46.jsonl
#
# Procesando lote 47 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 47 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_47.jsonl
#
# Procesando lote 48 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 48 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_48.jsonl
#
# Procesando lote 49 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 49 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_49.jsonl
#
# Procesando lote 50 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 50 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_50.jsonl
#
# Procesando lote 51 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 51 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_51.jsonl
#
# Procesando lote 52 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 52 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_52.jsonl
#
# Procesando lote 53 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 53 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_53.jsonl
#
# Procesando lote 54 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 54 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_54.jsonl
#
# Procesando lote 55 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 55 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_55.jsonl
#
# Procesando lote 56 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 56 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_56.jsonl
#
# Procesando lote 57 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 57 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_57.jsonl
#
# Procesando lote 58 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 58 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_58.jsonl
#
# Procesando lote 59 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 59 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_59.jsonl
#
# Procesando lote 60 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 60 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_60.jsonl
#
# Procesando lote 61 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 61 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_61.jsonl
#
# Procesando lote 62 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 62 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_62.jsonl
#
# Procesando lote 63 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 63 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_63.jsonl
#
# Procesando lote 64 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 64 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_64.jsonl
#
# Procesando lote 65 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 65 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_65.jsonl
#
# Procesando lote 66 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 66 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_66.jsonl
#
# Procesando lote 67 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 67 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_67.jsonl
#
# Procesando lote 68 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 68 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_68.jsonl
#
# Procesando lote 69 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 69 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_69.jsonl
#
# Procesando lote 70 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 70 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_70.jsonl
#
# Procesando lote 71 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 71 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_71.jsonl
#
# Procesando lote 72 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 72 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_72.jsonl
#
# Procesando lote 73 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 73 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_73.jsonl
#
# Procesando lote 74 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 74 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_74.jsonl
#
# Procesando lote 75 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 75 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_75.jsonl
#
# Procesando lote 76 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 76 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_76.jsonl
#
# Procesando lote 77 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 77 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_77.jsonl
#
# Procesando lote 78 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 78 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_78.jsonl
#
# Procesando lote 79 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 79 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_79.jsonl
#
# Procesando lote 80 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 80 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_80.jsonl
#
# Procesando lote 81 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 81 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_81.jsonl
#
# Procesando lote 82 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 82 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_82.jsonl
#
# Procesando lote 83 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 83 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_83.jsonl
#
# Procesando lote 84 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 84 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_84.jsonl
#
# Procesando lote 85 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 85 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_85.jsonl
#
# Procesando lote 86 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 86 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_86.jsonl
#
# Procesando lote 87 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 87 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_87.jsonl
#
# Procesando lote 88 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 88 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_88.jsonl
#
# Procesando lote 89 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 89 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_89.jsonl
#
# Procesando lote 90 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 90 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_90.jsonl
#
# Procesando lote 91 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 91 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_91.jsonl
#
# Procesando lote 92 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 92 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_92.jsonl
#
# Procesando lote 93 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 93 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_93.jsonl
#
# Procesando lote 94 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 94 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_94.jsonl
#
# Procesando lote 95 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 95 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_95.jsonl
#
# Procesando lote 96 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 96 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_96.jsonl
#
# Procesando lote 97 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 97 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_97.jsonl
#
# Procesando lote 98 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 98 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_98.jsonl
#
# Procesando lote 99 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 99 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_99.jsonl
#
# Procesando lote 100 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 100 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_100.jsonl
#
# Procesando lote 101 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 101 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_101.jsonl
#
# Procesando lote 102 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 102 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_102.jsonl
#
# Procesando lote 103 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 103 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_103.jsonl
#
# Procesando lote 104 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 104 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_104.jsonl
#
# Procesando lote 105 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 105 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_105.jsonl
#
# Procesando lote 106 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 106 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_106.jsonl
#
# Procesando lote 107 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 107 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_107.jsonl
#
# Procesando lote 108 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 108 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_108.jsonl
#
# Procesando lote 109 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 109 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_109.jsonl
#
# Procesando lote 110 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 110 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_110.jsonl
#
# Procesando lote 111 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 111 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_111.jsonl
#
# Procesando lote 112 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 112 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_112.jsonl
#
# Procesando lote 113 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 113 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_113.jsonl
#
# Procesando lote 114 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 114 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_114.jsonl
#
# Procesando lote 115 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 115 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_115.jsonl
#
# Procesando lote 116 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 116 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_116.jsonl
#
# Procesando lote 117 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 117 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_117.jsonl
#
# Procesando lote 118 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# ...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 469 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_469.jsonl
#
# Procesando lote 470 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 470 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_470.jsonl
#
# Procesando lote 471 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 471 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_471.jsonl
#
# Procesando lote 472 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 472 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_472.jsonl
#
# Procesando lote 473 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 473 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_473.jsonl
#
# Procesando lote 474 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 474 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_474.jsonl
#
# Procesando lote 475 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 475 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_475.jsonl
#
# Procesando lote 476 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 476 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_476.jsonl
#
# Procesando lote 477 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 477 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_477.jsonl
#
# Procesando lote 478 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 478 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_478.jsonl
#
# Procesando lote 479 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 479 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_479.jsonl
#
# Procesando lote 480 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 480 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_480.jsonl
#
# Procesando lote 481 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 481 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_481.jsonl
#
# Procesando lote 482 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 482 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_482.jsonl
#
# Procesando lote 483 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 483 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_483.jsonl
#
# Procesando lote 484 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 484 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_484.jsonl
#
# Procesando lote 485 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 485 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_485.jsonl
#
# Procesando lote 486 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 486 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_486.jsonl
#
# Procesando lote 487 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 487 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_487.jsonl
#
# Procesando lote 488 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 488 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_488.jsonl
#
# Procesando lote 489 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 489 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_489.jsonl
#
# Procesando lote 490 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 490 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_490.jsonl
#
# Procesando lote 491 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 491 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_491.jsonl
#
# Procesando lote 492 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 492 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_492.jsonl
#
# Procesando lote 493 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 493 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_493.jsonl
#
# Procesando lote 494 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 494 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_494.jsonl
#
# Procesando lote 495 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 495 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_495.jsonl
#
# Procesando lote 496 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# Procesando batch 3 con 250 textos...
# Procesando batch 4 con 250 textos...
# Subiendo lote 496 a GCS...
# Subido a GCS: embeddings/movies_and_series/embeddings_part_496.jsonl
#
# Procesando lote 497 con 1000 textos...
# Procesando batch 1 con 250 textos...
# Procesando batch 2 con 250 textos...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 142
#     140 if __name__ == "__main__":
#     141     print("Comenzando el proceso de batch...")
# --> 142     gcs_file_uri = process_and_upload_batches()
#     143     print(f"Embeddings subidos a: {gcs_file_uri}")
#
# Cell In[3], line 128, in process_and_upload_batches()
#     124     continue
#     126 print(f"\nProcesando lote {part_counter} con {len(batch_texts)} textos...")
# --> 128 embeddings = create_embeddings(batch_texts)
#     130 print(f"Subiendo lote {part_counter} a GCS...")
#     131 gcs_file_uri = save_embeddings_to_gcs(batch_ids, embeddings, part=part_counter)
#
# Cell In[3], line 74, in create_embeddings(texts, batch_size)
#      71     batch = texts[i:i + batch_size]
#      72     print(f"Procesando batch {i // batch_size + 1} con {len(batch)} textos...")
# ---> 74     embeddings = embedding_model.get_embeddings(batch)
#      75     all_embeddings.extend([e.values for e in embeddings])
#      77 return all_embeddings
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\vertexai\language_models\_language_models.py:2191, in _TextEmbeddingModel.get_embeddings(self, texts, auto_truncate, output_dimensionality)
#    2174 """Calculates embeddings for the given texts.
#    2175
#    2176 Args:
#    (...)
#    2183     A list of `TextEmbedding` objects.
#    2184 """
#    2185 prediction_request = self._prepare_text_embedding_request(
#    2186     texts=texts,
#    2187     auto_truncate=auto_truncate,
#    2188     output_dimensionality=output_dimensionality,
#    2189 )
# -> 2191 prediction_response = self._endpoint.predict(
#    2192     instances=prediction_request.instances,
#    2193     parameters=prediction_request.parameters,
#    2194 )
#    2196 return [
#    2197     TextEmbedding._parse_text_embedding_response(
#    2198         prediction_response, i_prediction
#    2199     )
#    2200     for i_prediction, _ in enumerate(prediction_response.predictions)
#    2201 ]
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\aiplatform\models.py:2439, in Endpoint.predict(self, instances, parameters, timeout, use_raw_predict, use_dedicated_endpoint)
#    2434 else:
#    2435     metadata = None
#    2437 return Prediction(
#    2438     predictions=[
# -> 2439         json_format.MessageToDict(item)
#    2440         for item in prediction_response.predictions.pb
#    2441     ],
#    2442     metadata=metadata,
#    2443     deployed_model_id=prediction_response.deployed_model_id,
#    2444     model_version_id=prediction_response.model_version_id,
#    2445     model_resource_name=prediction_response.model,
#    2446 )
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:162, in MessageToDict(message, always_print_fields_with_no_presence, preserving_proto_field_name, use_integers_for_enums, descriptor_pool, float_precision)
#     154 printer = _Printer(
#     155     preserving_proto_field_name,
#     156     use_integers_for_enums,
#    (...)
#     159     always_print_fields_with_no_presence,
#     160 )
#     161 # pylint: disable=protected-access
# --> 162 return printer._MessageToJsonObject(message)
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:208, in _Printer._MessageToJsonObject(self, message)
#     206   return self._WrapperMessageToJsonObject(message)
#     207 if full_name in _WKTJSONMETHODS:
# --> 208   return methodcaller(_WKTJSONMETHODS[full_name][0], message)(self)
#     209 js = {}
#     210 return self._RegularMessageToJsonObject(message, js)
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:379, in _Printer._ValueMessageToJsonObject(self, message)
#     377   value = getattr(message, which)
#     378 oneof_descriptor = message.DESCRIPTOR.fields_by_name[which]
# --> 379 return self._FieldToJsonObject(oneof_descriptor, value)
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:284, in _Printer._FieldToJsonObject(self, field, value)
#     282 """Converts field value according to Proto3 JSON Specification."""
#     283 if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 284   return self._MessageToJsonObject(value)
#     285 elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     286   if self.use_integers_for_enums:
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:208, in _Printer._MessageToJsonObject(self, message)
#     206   return self._WrapperMessageToJsonObject(message)
#     207 if full_name in _WKTJSONMETHODS:
# --> 208   return methodcaller(_WKTJSONMETHODS[full_name][0], message)(self)
#     209 js = {}
#     210 return self._RegularMessageToJsonObject(message, js)
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:390, in _Printer._StructMessageToJsonObject(self, message)
#     388 ret = {}
#     389 for key in fields:
# --> 390   ret[key] = self._ValueMessageToJsonObject(fields[key])
#     391 return ret
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:379, in _Printer._ValueMessageToJsonObject(self, message)
#     377   value = getattr(message, which)
#     378 oneof_descriptor = message.DESCRIPTOR.fields_by_name[which]
# --> 379 return self._FieldToJsonObject(oneof_descriptor, value)
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:284, in _Printer._FieldToJsonObject(self, field, value)
#     282 """Converts field value according to Proto3 JSON Specification."""
#     283 if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 284   return self._MessageToJsonObject(value)
#     285 elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     286   if self.use_integers_for_enums:
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:208, in _Printer._MessageToJsonObject(self, message)
#     206   return self._WrapperMessageToJsonObject(message)
#     207 if full_name in _WKTJSONMETHODS:
# --> 208   return methodcaller(_WKTJSONMETHODS[full_name][0], message)(self)
#     209 js = {}
#     210 return self._RegularMessageToJsonObject(message, js)
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:390, in _Printer._StructMessageToJsonObject(self, message)
#     388 ret = {}
#     389 for key in fields:
# --> 390   ret[key] = self._ValueMessageToJsonObject(fields[key])
#     391 return ret
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:363, in _Printer._ValueMessageToJsonObject(self, message)
#     361   return None
#     362 if which == 'list_value':
# --> 363   return self._ListValueMessageToJsonObject(message.list_value)
#     364 if which == 'number_value':
#     365   value = message.number_value
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:383, in _Printer._ListValueMessageToJsonObject(self, message)
#     381 def _ListValueMessageToJsonObject(self, message):
#     382   """Converts ListValue message according to Proto3 JSON Specification."""
# --> 383   return [self._ValueMessageToJsonObject(value) for value in message.values]
#
# File c:\Users\Agustín\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\json_format.py:366, in _Printer._ValueMessageToJsonObject(self, message)
#     364 if which == 'number_value':
#     365   value = message.number_value
# --> 366   if math.isinf(value):
#     367     raise ValueError(
#     368         'Fail to serialize Infinity for Value.number_value, '
#     369         'which would parse as string_value'
#     370     )
#     371   if math.isnan(value):
#
# KeyboardInterrupt:

# %%
import vertexai
from vertexai.language_models import TextEmbeddingModel
from google.cloud import bigquery, storage
import pandas as pd
import json
import os

# Config
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
LOCATION = "europe-southwest1"
BUCKET_NAME = "embeddings_new_bucket"
GCS_PREFIX = "embeddings/movies_and_series"
BQ_QUERY = "SELECT tmdb_id AS ID, title, genres, synopsis FROM `bubbo-dfba0.content.best_content_translated_py`"
EMBEDDING_MODEL = "text-multilingual-embedding-002"
BATCH_SIZE = 250

# Inicializar APIs
vertexai.init(project=PROJECT, location=LOCATION)
embedding_model = TextEmbeddingModel.from_pretrained(EMBEDDING_MODEL)
bq_client = bigquery.Client(project=PROJECT)
storage_client = storage.Client(project=PROJECT)


# 1. Obtener datos de BigQuery
def get_data_from_bigquery():
    print("Ejecutando la consulta en BigQuery...")
    job = bq_client.query(BQ_QUERY)
    iterator = job.result(page_size=BATCH_SIZE)
    pages = iterator.pages

    all_rows = []
    for page_num, page in enumerate(pages, start=1):
        print(f"Procesando página {page_num}...")
        all_rows.extend(page)

    all_rows = [list(row) for row in all_rows]
    columns = ['ID', 'title', 'genres', 'synopsis']
    df = pd.DataFrame(all_rows, columns=columns)

    df["combined"] = df.apply(
        lambda row: f"{row['title']}. Géneros: {row['genres']}. Sinopsis: {row['synopsis']}", axis=1
    )

    ids = df["ID"].astype(str).tolist()
    texts = df["combined"].astype(str).tolist()

    print(f"Se obtuvieron {len(ids)} registros.")
    return ids, texts


# 2. Crear embeddings por batch
def create_embeddings(texts, batch_size=BATCH_SIZE):
    all_embeddings = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i + batch_size]
        print(f"Procesando batch {i // batch_size + 1} con {len(batch)} textos...")
        embeddings = embedding_model.get_embeddings(batch)
        all_embeddings.extend([e.values for e in embeddings])
    return all_embeddings


# 3. Validar si el archivo ya existe en GCS
def gcs_file_exists(gcs_path):
    bucket = storage_client.bucket(BUCKET_NAME)
    blob = bucket.blob(gcs_path)
    return blob.exists()


# 4. Subir un solo archivo JSON a GCS
def upload_single_embedding_to_gcs(id, embedding):
    gcs_path = f"{GCS_PREFIX}/{id}.json"
    if gcs_file_exists(gcs_path):
        print(f"ID {id} ya existe. Saltando...")
        return

    temp_path = f"/tmp/{id}.json"
    with open(temp_path, "w") as f:
        json.dump({"id": id, "embedding": embedding}, f)

    bucket = storage_client.bucket(BUCKET_NAME)
    blob = bucket.blob(gcs_path)
    blob.upload_from_filename(temp_path)
    print(f"Subido: {gcs_path}")


# 5. Proceso principal
def process_and_upload_individual_embeddings():
    print("Iniciando el proceso de obtener datos y crear embeddings...")

    ids, texts = get_data_from_bigquery()
    if not ids or not texts:
        print("Error al obtener los datos. Terminando el proceso.")
        return ""

    part_counter = 1
    for i in range(0, len(texts), BATCH_SIZE):
        batch_ids = ids[i:i + BATCH_SIZE]
        batch_texts = texts[i:i + BATCH_SIZE]

        print(f"==> Procesando lote {i // BATCH_SIZE + 1} ({len(batch_ids)} registros)...")

        # Limitar el texto de cada ID a 12,000 tokens usando truncamiento
        batch_texts_limited = [truncate_text(text) for text in batch_texts]

        # Generar los embeddings para los textos truncados
        embeddings = create_embeddings(batch_texts_limited)

        # Subir cada embedding por separado a GCS
        for id, embedding in zip(batch_ids, embeddings):
            upload_single_embedding_to_gcs(id, embedding)

        part_counter += 1

    print("Todos los embeddings procesados y subidos.")
    return f"gs://{BUCKET_NAME}/{GCS_PREFIX}/"



# MAIN
if __name__ == "__main__":
    process_and_upload_individual_embeddings()
# Out:
# Iniciando el proceso de obtener datos y crear embeddings...
# Ejecutando la consulta en BigQuery...
# Procesando página 1...
# Procesando página 2...
# Procesando página 3...
# Procesando página 4...
# Procesando página 5...
# Procesando página 6...
# Procesando página 7...
# Procesando página 8...
# Procesando página 9...
# Procesando página 10...
# Procesando página 11...
# Procesando página 12...
# Procesando página 13...
# Procesando página 14...
# Procesando página 15...
# Procesando página 16...
# Procesando página 17...
# Procesando página 18...
# Procesando página 19...
# Procesando página 20...
# Procesando página 21...
# Procesando página 22...
# Procesando página 23...
# Procesando página 24...
# Procesando página 25...
# Procesando página 26...
# Procesando página 27...
# Procesando página 28...
# Procesando página 29...
# Procesando página 30...
# Procesando página 31...
# Procesando página 32...
# Procesando página 33...
# Procesando página 34...
# Procesando página 35...
# Procesando página 36...
# Procesando página 37...
# Procesando página 38...
# Procesando página 39...
# Procesando página 40...
# Procesando página 41...
# Procesando página 42...
# Procesando página 43...
# Procesando página 44...
# Procesando página 45...
# Procesando página 46...
# Procesando página 47...
# Procesando página 48...
# Procesando página 49...
# Procesando página 50...
# Procesando página 51...
# Procesando página 52...
# Procesando página 53...
# Procesando página 54...
# Procesando página 55...
# Procesando página 56...
# Procesando página 57...
# Procesando página 58...
# Procesando página 59...
# Procesando página 60...
# Procesando página 61...
# Procesando página 62...
# Procesando página 63...
# Procesando página 64...
# Procesando página 65...
# Procesando página 66...
# Procesando página 67...
# Procesando página 68...
# Procesando página 69...
# Procesando página 70...
# Procesando página 71...
# Procesando página 72...
# Procesando página 73...
# Procesando página 74...
# Procesando página 75...
# Procesando página 76...
# Procesando página 77...
# Procesando página 78...
# Procesando página 79...
# Procesando página 80...
# Procesando página 81...
# Procesando página 82...
# Procesando página 83...
# Procesando página 84...
# Procesando página 85...
# Procesando página 86...
# Procesando página 87...
# Procesando página 88...
# Procesando página 89...
# Procesando página 90...
# Procesando página 91...
# Procesando página 92...
# Procesando página 93...
# Procesando página 94...
# Procesando página 95...
# Procesando página 96...
# Procesando página 97...
# Procesando página 98...
# Procesando página 99...
# Procesando página 100...
# Procesando página 101...

# %%
########## VALIDADOR
from google.cloud import bigquery, storage
import os

# Config (ajustá si estás en otro archivo)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../../bubbo-dfba0-47e395cdcdc7.json"

PROJECT = "bubbo-dfba0"
BUCKET_NAME = "embeddings_new_bucket"
GCS_PREFIX = "embeddings/movies_and_series"

# Inicializar clientes
bq_client = bigquery.Client(project=PROJECT)
storage_client = storage.Client(project=PROJECT)

# 1. Obtener todos los IDs desde BigQuery
def get_all_ids_from_bigquery():
    query = "SELECT tmdb_id AS ID FROM `bubbo-dfba0.content.best_content_translated_py`"
    query_job = bq_client.query(query)
    results = query_job.result()
    return set(str(row.ID) for row in results)

# 2. Obtener todos los archivos existentes en GCS
def get_all_ids_in_gcs():
    bucket = storage_client.bucket(BUCKET_NAME)
    blobs = bucket.list_blobs(prefix=GCS_PREFIX + "/")
    ids_in_gcs = set()

    for blob in blobs:
        filename = blob.name.split("/")[-1]
        if filename.endswith(".json"):
            id_str = filename.replace(".json", "")
            ids_in_gcs.add(id_str)

    return ids_in_gcs

# 3. Comparar y mostrar faltantes
def find_missing_embeddings():
    print("Validando archivos en GCS contra BigQuery...")

    bq_ids = get_all_ids_from_bigquery()
    gcs_ids = get_all_ids_in_gcs()

    missing_ids = sorted(bq_ids - gcs_ids)

    print(f"Total en BigQuery: {len(bq_ids)}")
    print(f"Total en GCS: {len(gcs_ids)}")
    print(f"Faltan: {len(missing_ids)} embeddings")

    if missing_ids:
        print("Algunos ejemplos:", missing_ids[:10])

    return missing_ids

# Ejecutar validador
missing_ids = find_missing_embeddings()
